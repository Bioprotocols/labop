# %%
from copy import deepcopy

import rdflib as rdf
from rdflib import OWL, RDF, RDFS

from typing import List, Tuple, Optional, Any
Triple = Tuple[Any, Any, Any]

# %%
g = rdf.Graph()

# %%
g.parse('../paml/paml.ttl', format='turtle')
# Out:
# <Graph identifier=N2029fcab25f848a2bbd4b39663c16a83 (<class 'rdflib.graph.Graph'>)>

# %%
q = """
    PREFIX owl: <%s>

    SELECT ?rel
    {
        # ?_p a owl:Restriction ;
            # ?rel ?_x .
    }
"""%rdf.OWL
q
# Out:
# '\n    PREFIX owl: <http://www.w3.org/2002/07/owl#>\n\n    SELECT ?rel\n    {\n        ?_p a owl:Restriction ;\n            ?rel ?_x .\n    }\n'

# %%
for r in g.query(q):
    print(r["rel"])
# Out:
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#comment
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onClass
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onClass
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#comment
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#allValuesFrom
# http://www.w3.org/2002/07/owl#minCardinality
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/2002/07/owl#maxCardinality
# http://www.w3.org/2002/07/owl#onProperty
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type

# %%
rels = [OWL.allValuesFrom, OWL.minCardinality, OWL.maxCardinality, RDF.type]
ignore = [OWL.onProperty, RDFS.comment]

# %%
q = """
    PREFIX owl: <%s>

    SELECT ?r
    {
        # ?r a owl:Restriction .
    }
"""%rdf.OWL


restrs = [r["r"] for r in g.query(q)]
restrs
# Out:
# [rdflib.term.BNode('ub8bL232C5'),
#  rdflib.term.BNode('ub9bL490C4'),
#  rdflib.term.BNode('ub8bL549C9'),
#  rdflib.term.BNode('ub8bL548C9'),
#  rdflib.term.BNode('ub8bL319C9'),
#  rdflib.term.BNode('ub8bL550C9'),
#  rdflib.term.BNode('ub9bL273C5'),
#  rdflib.term.BNode('ub8bL640C5'),
#  rdflib.term.BNode('ub9bL130C5'),
#  rdflib.term.BNode('ub8bL383C5'),
#  rdflib.term.BNode('ub8bL376C5'),
#  rdflib.term.BNode('ub8bL621C9'),
#  rdflib.term.BNode('ub8bL112C9'),
#  rdflib.term.BNode('ub8bL405C5'),
#  rdflib.term.BNode('ub8bL518C5'),
#  rdflib.term.BNode('ub9bL355C13'),
#  rdflib.term.BNode('ub8bL243C5'),
#  rdflib.term.BNode('ub8bL349C5'),
#  rdflib.term.BNode('ub8bL373C5'),
#  rdflib.term.BNode('ub8bL664C5'),
#  rdflib.term.BNode('ub9bL435C29'),
#  rdflib.term.BNode('ub9bL156C5'),
#  rdflib.term.BNode('ub8bL83C20'),
#  rdflib.term.BNode('ub8bL367C9'),
#  rdflib.term.BNode('ub8bL334C5'),
#  rdflib.term.BNode('ub8bL137C9'),
#  rdflib.term.BNode('ub8bL622C9'),
#  rdflib.term.BNode('ub8bL377C5'),
#  rdflib.term.BNode('ub8bL98C5'),
#  rdflib.term.BNode('ub8bL111C9'),
#  rdflib.term.BNode('ub8bL375C5'),
#  rdflib.term.BNode('ub8bL407C5'),
#  rdflib.term.BNode('ub8bL381C5'),
#  rdflib.term.BNode('ub8bL164C5'),
#  rdflib.term.BNode('ub8bL368C9'),
#  rdflib.term.BNode('ub8bL607C9'),
#  rdflib.term.BNode('ub8bL626C9'),
#  rdflib.term.BNode('ub8bL152C9'),
#  rdflib.term.BNode('ub8bL369C9'),
#  rdflib.term.BNode('ub8bL151C9'),
#  rdflib.term.BNode('ub8bL126C9'),
#  rdflib.term.BNode('ub8bL113C9'),
#  rdflib.term.BNode('ub8bL207C5'),
#  rdflib.term.BNode('ub8bL274C5'),
#  rdflib.term.BNode('ub8bL124C9'),
#  rdflib.term.BNode('ub8bL139C9'),
#  rdflib.term.BNode('ub9bL496C5'),
#  rdflib.term.BNode('ub8bL520C5'),
#  rdflib.term.BNode('ub9bL78C5'),
#  rdflib.term.BNode('ub8bL570C5'),
#  rdflib.term.BNode('ub8bL382C5'),
#  rdflib.term.BNode('ub8bL336C5'),
#  rdflib.term.BNode('ub9bL361C13'),
#  rdflib.term.BNode('ub8bL629C9'),
#  rdflib.term.BNode('ub8bL370C9'),
#  rdflib.term.BNode('ub8bL406C5'),
#  rdflib.term.BNode('ub8bL374C5'),
#  rdflib.term.BNode('ub9bL393C13'),
#  rdflib.term.BNode('ub8bL100C5'),
#  rdflib.term.BNode('ub8bL569C5'),
#  rdflib.term.BNode('ub9bL128C5'),
#  rdflib.term.BNode('ub9bL190C5'),
#  rdflib.term.BNode('ub8bL620C14'),
#  rdflib.term.BNode('ub8bL606C9'),
#  rdflib.term.BNode('ub8bL198C5'),
#  rdflib.term.BNode('ub9bL297C5'),
#  rdflib.term.BNode('ub9bL158C5'),
#  rdflib.term.BNode('ub8bL441C5'),
#  rdflib.term.BNode('ub8bL519C5'),
#  rdflib.term.BNode('ub8bL624C9'),
#  rdflib.term.BNode('ub8bL541C9'),
#  rdflib.term.BNode('ub8bL663C5'),
#  rdflib.term.BNode('ub8bL608C9'),
#  rdflib.term.BNode('ub8bL661C5'),
#  rdflib.term.BNode('ub8bL641C5'),
#  rdflib.term.BNode('ub9bL231C5'),
#  rdflib.term.BNode('ub8bL660C5'),
#  rdflib.term.BNode('ub8bL240C5'),
#  rdflib.term.BNode('ub8bL276C5'),
#  rdflib.term.BNode('ub9bL79C5'),
#  rdflib.term.BNode('ub9bL81C5'),
#  rdflib.term.BNode('ub8bL542C9'),
#  rdflib.term.BNode('ub8bL351C5'),
#  rdflib.term.BNode('ub8bL99C5'),
#  rdflib.term.BNode('ub8bL176C5'),
#  rdflib.term.BNode('ub8bL627C9'),
#  rdflib.term.BNode('ub8bL138C9'),
#  rdflib.term.BNode('ub8bL84C20'),
#  rdflib.term.BNode('ub8bL625C9'),
#  rdflib.term.BNode('ub8bL296C5'),
#  rdflib.term.BNode('ub8bL200C5'),
#  rdflib.term.BNode('ub8bL234C5'),
#  rdflib.term.BNode('ub9bL233C5'),
#  rdflib.term.BNode('ub9bL441C29'),
#  rdflib.term.BNode('ub8bL298C5'),
#  rdflib.term.BNode('ub9bL189C5'),
#  rdflib.term.BNode('ub8bL366C9'),
#  rdflib.term.BNode('ub8bL439C5'),
#  rdflib.term.BNode('ub8bL460C5'),
#  rdflib.term.BNode('ub8bL642C5'),
#  rdflib.term.BNode('ub9bL271C5'),
#  rdflib.term.BNode('ub9bL487C5'),
#  rdflib.term.BNode('ub9bL493C5'),
#  rdflib.term.BNode('ub8bL384C5'),
#  rdflib.term.BNode('ub9bL398C13'),
#  rdflib.term.BNode('ub8bL459C5'),
#  rdflib.term.BNode('ub8bL125C9'),
#  rdflib.term.BNode('ub8bL180C5'),
#  rdflib.term.BNode('ub8bL380C5'),
#  rdflib.term.BNode('ub8bL517C5'),
#  rdflib.term.BNode('ub9bL235C5'),
#  rdflib.term.BNode('ub8bL665C5'),
#  rdflib.term.BNode('ub8bL150C9'),
#  rdflib.term.BNode('ub8bL623C9'),
#  rdflib.term.BNode('ub8bL379C5'),
#  rdflib.term.BNode('ub9bL187C5'),
#  rdflib.term.BNode('ub8bL205C5'),
#  rdflib.term.BNode('ub8bL628C9'),
#  rdflib.term.BNode('ub8bL378C5'),
#  rdflib.term.BNode('ub8bL178C5'),
#  rdflib.term.BNode('ub8bL662C5')]

# %%
def is_bad_restr(restr, graph) -> bool :
    rrs = set()
    for _r, rel, _x in graph.triples((restr, None, None)):
        if rel in rels:
            rrs.add(rel)
    assert len(rrs) > 0, f"No components to restriction {restr}"
    return len(rrs) > 1

# %%
bad = [x for x in restrs if is_bad_restr(x, g)]
bad
# Out:
# [rdflib.term.BNode('ub8bL232C5'),
#  rdflib.term.BNode('ub9bL490C4'),
#  rdflib.term.BNode('ub8bL549C9'),
#  rdflib.term.BNode('ub8bL548C9'),
#  rdflib.term.BNode('ub8bL319C9'),
#  rdflib.term.BNode('ub8bL550C9'),
#  rdflib.term.BNode('ub9bL273C5'),
#  rdflib.term.BNode('ub8bL640C5'),
#  rdflib.term.BNode('ub9bL130C5'),
#  rdflib.term.BNode('ub8bL383C5'),
#  rdflib.term.BNode('ub8bL376C5'),
#  rdflib.term.BNode('ub8bL621C9'),
#  rdflib.term.BNode('ub8bL112C9'),
#  rdflib.term.BNode('ub8bL405C5'),
#  rdflib.term.BNode('ub8bL518C5'),
#  rdflib.term.BNode('ub9bL355C13'),
#  rdflib.term.BNode('ub8bL243C5'),
#  rdflib.term.BNode('ub8bL349C5'),
#  rdflib.term.BNode('ub8bL373C5'),
#  rdflib.term.BNode('ub8bL664C5'),
#  rdflib.term.BNode('ub9bL435C29'),
#  rdflib.term.BNode('ub9bL156C5'),
#  rdflib.term.BNode('ub8bL83C20'),
#  rdflib.term.BNode('ub8bL367C9'),
#  rdflib.term.BNode('ub8bL334C5'),
#  rdflib.term.BNode('ub8bL137C9'),
#  rdflib.term.BNode('ub8bL622C9'),
#  rdflib.term.BNode('ub8bL377C5'),
#  rdflib.term.BNode('ub8bL98C5'),
#  rdflib.term.BNode('ub8bL111C9'),
#  rdflib.term.BNode('ub8bL375C5'),
#  rdflib.term.BNode('ub8bL407C5'),
#  rdflib.term.BNode('ub8bL381C5'),
#  rdflib.term.BNode('ub8bL164C5'),
#  rdflib.term.BNode('ub8bL368C9'),
#  rdflib.term.BNode('ub8bL607C9'),
#  rdflib.term.BNode('ub8bL626C9'),
#  rdflib.term.BNode('ub8bL152C9'),
#  rdflib.term.BNode('ub8bL369C9'),
#  rdflib.term.BNode('ub8bL151C9'),
#  rdflib.term.BNode('ub8bL126C9'),
#  rdflib.term.BNode('ub8bL113C9'),
#  rdflib.term.BNode('ub8bL207C5'),
#  rdflib.term.BNode('ub8bL274C5'),
#  rdflib.term.BNode('ub8bL124C9'),
#  rdflib.term.BNode('ub8bL139C9'),
#  rdflib.term.BNode('ub9bL496C5'),
#  rdflib.term.BNode('ub8bL520C5'),
#  rdflib.term.BNode('ub9bL78C5'),
#  rdflib.term.BNode('ub8bL570C5'),
#  rdflib.term.BNode('ub8bL382C5'),
#  rdflib.term.BNode('ub8bL336C5'),
#  rdflib.term.BNode('ub9bL361C13'),
#  rdflib.term.BNode('ub8bL629C9'),
#  rdflib.term.BNode('ub8bL370C9'),
#  rdflib.term.BNode('ub8bL406C5'),
#  rdflib.term.BNode('ub8bL374C5'),
#  rdflib.term.BNode('ub9bL393C13'),
#  rdflib.term.BNode('ub8bL100C5'),
#  rdflib.term.BNode('ub8bL569C5'),
#  rdflib.term.BNode('ub9bL128C5'),
#  rdflib.term.BNode('ub9bL190C5'),
#  rdflib.term.BNode('ub8bL620C14'),
#  rdflib.term.BNode('ub8bL606C9'),
#  rdflib.term.BNode('ub8bL198C5'),
#  rdflib.term.BNode('ub9bL297C5'),
#  rdflib.term.BNode('ub9bL158C5'),
#  rdflib.term.BNode('ub8bL441C5'),
#  rdflib.term.BNode('ub8bL519C5'),
#  rdflib.term.BNode('ub8bL624C9'),
#  rdflib.term.BNode('ub8bL541C9'),
#  rdflib.term.BNode('ub8bL663C5'),
#  rdflib.term.BNode('ub8bL608C9'),
#  rdflib.term.BNode('ub8bL661C5'),
#  rdflib.term.BNode('ub8bL641C5'),
#  rdflib.term.BNode('ub9bL231C5'),
#  rdflib.term.BNode('ub8bL660C5'),
#  rdflib.term.BNode('ub8bL240C5'),
#  rdflib.term.BNode('ub8bL276C5'),
#  rdflib.term.BNode('ub9bL79C5'),
#  rdflib.term.BNode('ub9bL81C5'),
#  rdflib.term.BNode('ub8bL542C9'),
#  rdflib.term.BNode('ub8bL351C5'),
#  rdflib.term.BNode('ub8bL99C5'),
#  rdflib.term.BNode('ub8bL176C5'),
#  rdflib.term.BNode('ub8bL627C9'),
#  rdflib.term.BNode('ub8bL138C9'),
#  rdflib.term.BNode('ub8bL84C20'),
#  rdflib.term.BNode('ub8bL625C9'),
#  rdflib.term.BNode('ub8bL296C5'),
#  rdflib.term.BNode('ub8bL200C5'),
#  rdflib.term.BNode('ub8bL234C5'),
#  rdflib.term.BNode('ub9bL233C5'),
#  rdflib.term.BNode('ub9bL441C29'),
#  rdflib.term.BNode('ub8bL298C5'),
#  rdflib.term.BNode('ub9bL189C5'),
#  rdflib.term.BNode('ub8bL366C9'),
#  rdflib.term.BNode('ub8bL439C5'),
#  rdflib.term.BNode('ub8bL460C5'),
#  rdflib.term.BNode('ub8bL642C5'),
#  rdflib.term.BNode('ub9bL271C5'),
#  rdflib.term.BNode('ub9bL487C5'),
#  rdflib.term.BNode('ub9bL493C5'),
#  rdflib.term.BNode('ub8bL384C5'),
#  rdflib.term.BNode('ub9bL398C13'),
#  rdflib.term.BNode('ub8bL459C5'),
#  rdflib.term.BNode('ub8bL125C9'),
#  rdflib.term.BNode('ub8bL180C5'),
#  rdflib.term.BNode('ub8bL380C5'),
#  rdflib.term.BNode('ub8bL517C5'),
#  rdflib.term.BNode('ub9bL235C5'),
#  rdflib.term.BNode('ub8bL665C5'),
#  rdflib.term.BNode('ub8bL150C9'),
#  rdflib.term.BNode('ub8bL623C9'),
#  rdflib.term.BNode('ub8bL379C5'),
#  rdflib.term.BNode('ub9bL187C5'),
#  rdflib.term.BNode('ub8bL205C5'),
#  rdflib.term.BNode('ub8bL628C9'),
#  rdflib.term.BNode('ub8bL378C5'),
#  rdflib.term.BNode('ub8bL178C5'),
#  rdflib.term.BNode('ub8bL662C5')]

# %%
def describe_bad_restr(b, g: rdf.Graph):
    nsm = rdf.namespace.NamespaceManager(g)
    nsm.bind('owl', OWL)
    triples = g.triples((b, None, None))
    for x, _y, z in g.triples((b, RDF.type, None)):
        print("%s a %s"%(x, z))
    for _, y, z in triples:
        if y != RDF.type:
            print("\t%s %s"%(nsm.normalizeUri(y), nsm.normalizeUri(z)))

# %%
describe_bad_restr(bad[0], g)
# Out:
# ub8bL232C5 a http://www.w3.org/2002/07/owl#Restriction
# 	owl:onProperty uml:firstEventValue
# 	owl:minCardinality <1>
# 	owl:maxCardinality <1>
# 	owl:allValuesFrom uml:OrderedPropertyValue

# %%
def translate_bad_restr(b, g):
    nsm = rdf.namespace.NamespaceManager(g)
    nsm.bind('owl', OWL)
    triples = g.triples((b, None, None))
    types = [z for _x, _y, z in g.triples((b, RDF.type, None))]
    props = [z for _x, _y, z in g.triples((b, OWL.onProperty, None))]
    assert len(props) == 1
    prop = props[0]

# %%
def translate_bad_restr(b, g):
    comment: Optional[Any] = None
    new_bnodes: List[rdf.BNode] = []
    to_add: List[Triple] = []
    to_delete: List[Triple] = \
        [tuple for tuple in g.triples((b, None, None))]
    nsm = rdf.namespace.NamespaceManager(g)
    nsm.bind('owl', OWL)
    def normalize(x):
        return nsm.normalizeUri(x)
    def find_children():
        child_triples=g.triples((None, RDFS.subClassOf, b))
        children = [x for x, _, _ in child_triples]
        assert len(children) >= 1
        return children
    triples = g.triples((b, None, None))
    types = [z for _x, _y, z in g.triples((b, RDF.type, None))]
    props = [z for _x, _y, z in g.triples((b, OWL.onProperty, None))]
    comments = [z for _x, _y, z in g.triples((b, RDFS.comment, None))]
    assert len(props) == 1
    assert len(comments) <= 1
    assert len(types) == 1
    prop = props[0]
    if comments:
        comment = comments[0]

    for _, y, z in triples:
        if y not in set(ignore) | {RDF.type}:
            bnode = rdf.BNode()
            new_bnodes.append(bnode)
            print(f"{nsm.normalizeUri(bnode)} a {nsm.normalizeUri(types[0])} ;")
            to_add.append((bnode, RDF.type, types[0]))
            print(f"\towl:onProperty {nsm.normalizeUri(prop)} ;")
            to_add.append((bnode, OWL.onProperty, prop))
            print(f"\t{nsm.normalizeUri(y)} {nsm.normalizeUri(z)}", end='')
            to_add.append((bnode, y, z))
            if comment:
                print(f"\n\trdfs:comment {nsm.normalizeUri(comment)} .")
                to_add.append((bnode, RDFS.comment, comment))
            else:
                print(".")
    print("Children of this restriction are:")
    for x in find_children():
        print(f"\t{x}")
        print(f"\tRemove {normalize(x)} rdfs:subClassOf {normalize(b)}")
        to_delete.append((x, RDFS.subClassOf, b))
        for nb in new_bnodes:
            print(f"\t{x} {nsm.normalizeUri(RDFS.subClassOf)} {nsm.normalizeUri(nb)}")
            to_add.append((x, RDFS.subClassOf, nb))

    return to_add, to_delete

# %%
translate_bad_restr(bad[0], g)
# Out:
# <Ne501e8f57b054977af0bc6276ae6faa2> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <1>.
# <N107f89530b1c4672b69da6831047c8c3> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <1>.
# <Neda0f48169cb416c8b37bd070f336ed1> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeObservation
# 	Remove uml:TimeObservation rdfs:subClassOf <ub8bL232C5>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Ne501e8f57b054977af0bc6276ae6faa2>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N107f89530b1c4672b69da6831047c8c3>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Neda0f48169cb416c8b37bd070f336ed1>
# ([(rdflib.term.BNode('Ne501e8f57b054977af0bc6276ae6faa2'),
#    rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction')),
#   (rdflib.term.BNode('Ne501e8f57b054977af0bc6276ae6faa2'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onProperty'),
#    rdflib.term.URIRef('http://bioprotocols.org/uml#firstEventValue')),
#   (rdflib.term.BNode('Ne501e8f57b054977af0bc6276ae6faa2'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#minCardinality'),
#    rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger'))),
#   (rdflib.term.BNode('N107f89530b1c4672b69da6831047c8c3'),
#    rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction')),
#   (rdflib.term.BNode('N107f89530b1c4672b69da6831047c8c3'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onProperty'),
#    rdflib.term.URIRef('http://bioprotocols.org/uml#firstEventValue')),
#   (rdflib.term.BNode('N107f89530b1c4672b69da6831047c8c3'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#maxCardinality'),
#    rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger'))),
#   (rdflib.term.BNode('Neda0f48169cb416c8b37bd070f336ed1'),
#    rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction')),
#   (rdflib.term.BNode('Neda0f48169cb416c8b37bd070f336ed1'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onProperty'),
#    rdflib.term.URIRef('http://bioprotocols.org/uml#firstEventValue')),
#   (rdflib.term.BNode('Neda0f48169cb416c8b37bd070f336ed1'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#allValuesFrom'),
#    rdflib.term.URIRef('http://bioprotocols.org/uml#OrderedPropertyValue')),
#   (rdflib.term.URIRef('http://bioprotocols.org/uml#TimeObservation'),
#    rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#    rdflib.term.BNode('Ne501e8f57b054977af0bc6276ae6faa2')),
#   (rdflib.term.URIRef('http://bioprotocols.org/uml#TimeObservation'),
#    rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#    rdflib.term.BNode('N107f89530b1c4672b69da6831047c8c3')),
#   (rdflib.term.URIRef('http://bioprotocols.org/uml#TimeObservation'),
#    rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#    rdflib.term.BNode('Neda0f48169cb416c8b37bd070f336ed1'))],
#  [(rdflib.term.BNode('ub8bL232C5'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onProperty'),
#    rdflib.term.URIRef('http://bioprotocols.org/uml#firstEventValue')),
#   (rdflib.term.BNode('ub8bL232C5'),
#    rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction')),
#   (rdflib.term.BNode('ub8bL232C5'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#minCardinality'),
#    rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger'))),
#   (rdflib.term.BNode('ub8bL232C5'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#maxCardinality'),
#    rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger'))),
#   (rdflib.term.BNode('ub8bL232C5'),
#    rdflib.term.URIRef('http://www.w3.org/2002/07/owl#allValuesFrom'),
#    rdflib.term.URIRef('http://bioprotocols.org/uml#OrderedPropertyValue')),
#   (rdflib.term.URIRef('http://bioprotocols.org/uml#TimeObservation'),
#    rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#    rdflib.term.BNode('ub8bL232C5'))])

# %%
bad[0]
# Out:
# rdflib.term.BNode('ub8bL232C5')

# %%
rdf.namespace.NamespaceManager(g).normalizeUri(bad[0])
# Out:
# '<ub8bL232C5>'

# %%
def repair_all_bad_restrictions(bad: List[rdf.BNode], g: rdf.Graph):
    all_adds: List[Triple] = []
    all_deletes: List[Triple] = []
    for x in bad:
        to_add, to_delete = translate_bad_restr(x, g)
        all_adds += to_add
        all_deletes += to_delete
    for x in all_adds:
        g.add(x)
    for x in all_deletes:
        g.remove(x)
    return g

# %%
for x in g.triples((None, None, None)):
    print(x)
    break
# Out:
# (rdflib.term.BNode('ub8bL232C5'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'))

# %%
new_g = deepcopy(g)

repair_all_bad_restrictions(bad, new_g)
# Out:
# Type of container used for storing the samples. The size and dimension may not match that of the array: it is up to execution to lay out the array in one or more  does not look like a valid URI, trying to serialize this will break.
# Type of container used for storing the samples. The size and dimension may not match that of the array: it is up to execution to lay out the array in one or more  does not look like a valid URI, trying to serialize this will break.
# Type of container used for storing the samples. The size and dimension may not match that of the array: it is up to execution to lay out the array in one or more  does not look like a valid URI, trying to serialize this will break.
# N-dimensional array of URI for specification or  does not look like a valid URI, trying to serialize this will break.
# N-dimensional array of URI for specification or  does not look like a valid URI, trying to serialize this will break.
# N-dimensional array of URI for specification or  does not look like a valid URI, trying to serialize this will break.
# <N31f7179b3e96467e94b942076fa6356a> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <1>.
# <Nc31c87f93dce4e978dae168f741ac463> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# <N1791620d9a0b46da958add2c90ce7b1d> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeObservation
# 	Remove uml:TimeObservation rdfs:subClassOf <ub8bL232C5>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N31f7179b3e96467e94b942076fa6356a>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Nc31c87f93dce4e978dae168f741ac463>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N1791620d9a0b46da958add2c90ce7b1d>
# <Ne470706150654787aa57a2711c4642e4> a owl:Restriction ;
# 	owl:onProperty paml:queryString ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ContainerSpec
# 	Remove paml:ContainerSpec rdfs:subClassOf <ub9bL490C4>
# 	http://bioprotocols.org/paml#ContainerSpec rdfs:subClassOf <Ne470706150654787aa57a2711c4642e4>
# <N1cda63d22b904bc189caa4df617fec5c> a owl:Restriction ;
# 	owl:onProperty uml:parameter ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityParameterNode
# 	Remove uml:ActivityParameterNode rdfs:subClassOf <ub8bL549C9>
# 	http://bioprotocols.org/uml#ActivityParameterNode rdfs:subClassOf <N1cda63d22b904bc189caa4df617fec5c>
# <Nf0622ce30d5f4b468e021d0ff57edfda> a owl:Restriction ;
# 	owl:onProperty uml:parameter ;
# 	owl:allValuesFrom uml:Parameter.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityParameterNode
# 	Remove uml:ActivityParameterNode rdfs:subClassOf <ub8bL548C9>
# 	http://bioprotocols.org/uml#ActivityParameterNode rdfs:subClassOf <Nf0622ce30d5f4b468e021d0ff57edfda>
# <N464f7df095fb470c8eafc3ed5a7530f6> a owl:Restriction ;
# 	owl:onProperty uml:constrainedElement ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Constraint
# 	Remove uml:Constraint rdfs:subClassOf <ub8bL319C9>
# 	http://bioprotocols.org/uml#Constraint rdfs:subClassOf <N464f7df095fb470c8eafc3ed5a7530f6>
# <N6a89a66184f84fdd8202a703f4aa2ee6> a owl:Restriction ;
# 	owl:onProperty uml:parameter ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityParameterNode
# 	Remove uml:ActivityParameterNode rdfs:subClassOf <ub8bL550C9>
# 	http://bioprotocols.org/uml#ActivityParameterNode rdfs:subClassOf <N6a89a66184f84fdd8202a703f4aa2ee6>
# <Na8b8564c50ee4eec89bb097fea4afce6> a owl:Restriction ;
# 	owl:onProperty paml:incomingFlow ;
# 	owl:allValuesFrom paml:ActivityEdgeFlow.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ActivityNodeExecution
# 	Remove paml:ActivityNodeExecution rdfs:subClassOf <ub9bL273C5>
# 	http://bioprotocols.org/paml#ActivityNodeExecution rdfs:subClassOf <Na8b8564c50ee4eec89bb097fea4afce6>
# <N1b7e4d80ed0544a4bbc06037620f5f5b> a owl:Restriction ;
# 	owl:onProperty uml:value ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValuePin
# 	Remove uml:ValuePin rdfs:subClassOf <ub8bL640C5>
# 	http://bioprotocols.org/uml#ValuePin rdfs:subClassOf <N1b7e4d80ed0544a4bbc06037620f5f5b>
# <Nd3be883f410b4fe1b89ae993070488b5> a owl:Restriction ;
# 	owl:onProperty paml:parameterValue ;
# 	owl:allValuesFrom uml:LiteralSpecification.
# <Nd4c2d36f093248b292706f213417e711> a owl:Restriction ;
# 	owl:onProperty paml:parameterValue ;
# 	owl:maxCardinality <1>.
# <Nc2c9a2a6cd9d41d6b3436b2d6aeff619> a owl:Restriction ;
# 	owl:onProperty paml:parameterValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ParameterValue
# 	Remove paml:ParameterValue rdfs:subClassOf <ub9bL130C5>
# 	http://bioprotocols.org/paml#ParameterValue rdfs:subClassOf <Nd3be883f410b4fe1b89ae993070488b5>
# 	http://bioprotocols.org/paml#ParameterValue rdfs:subClassOf <Nd4c2d36f093248b292706f213417e711>
# 	http://bioprotocols.org/paml#ParameterValue rdfs:subClassOf <Nc2c9a2a6cd9d41d6b3436b2d6aeff619>
# <N9f7e8ef8b46849f2a4fdfce0ccc9cfe6> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL383C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N9f7e8ef8b46849f2a4fdfce0ccc9cfe6>
# <N41aa2262b18e41e3979b8cc133c522ba> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL376C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N41aa2262b18e41e3979b8cc133c522ba>
# <Nfb86257123384bdaaa199630f323d73f> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL621C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Nfb86257123384bdaaa199630f323d73f>
# <Nae96dcfe10b2433fae69cfb546e1923c> a owl:Restriction ;
# 	owl:onProperty uml:integerValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralInteger
# 	Remove uml:LiteralInteger rdfs:subClassOf <ub8bL112C9>
# 	http://bioprotocols.org/uml#LiteralInteger rdfs:subClassOf <Nae96dcfe10b2433fae69cfb546e1923c>
# <Nff58c53a20e6488a9c90525c6f0183a1> a owl:Restriction ;
# 	owl:onProperty uml:precondition ;
# 	owl:allValuesFrom uml:Constraint.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Behavior
# 	Remove uml:Behavior rdfs:subClassOf <ub8bL405C5>
# 	http://bioprotocols.org/uml#Behavior rdfs:subClassOf <Nff58c53a20e6488a9c90525c6f0183a1>
# <Ndb1e2f6806674b92878b8714402bc263> a owl:Restriction ;
# 	owl:onProperty uml:decisionInput ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub8bL518C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <Ndb1e2f6806674b92878b8714402bc263>
# <N120fa2d706f4434eaff73fb66917fdae> a owl:Restriction ;
# 	owl:onProperty paml:containerType ;
# 	owl:minCardinality <1>
# 	rdfs:comment <Type of container used for storing the samples. The size and dimension may not match that of the array: it is up to execution to lay out the array in one or more containers> .
# <Ned670649cbee486e9ca5c5dec35d4dad> a owl:Restriction ;
# 	owl:onProperty paml:containerType ;
# 	owl:allValuesFrom xsd:anyURI
# 	rdfs:comment <Type of container used for storing the samples. The size and dimension may not match that of the array: it is up to execution to lay out the array in one or more containers> .
# <N3952ee604dc642b8b9835d52f08f21ff> a owl:Restriction ;
# 	owl:onProperty paml:containerType ;
# 	owl:maxCardinality <1>
# 	rdfs:comment <Type of container used for storing the samples. The size and dimension may not match that of the array: it is up to execution to lay out the array in one or more containers> .
# Children of this restriction are:
# 	http://bioprotocols.org/paml#SampleArray
# 	Remove paml:SampleArray rdfs:subClassOf <ub9bL355C13>
# 	http://bioprotocols.org/paml#SampleArray rdfs:subClassOf <N120fa2d706f4434eaff73fb66917fdae>
# 	http://bioprotocols.org/paml#SampleArray rdfs:subClassOf <Ned670649cbee486e9ca5c5dec35d4dad>
# 	http://bioprotocols.org/paml#SampleArray rdfs:subClassOf <N3952ee604dc642b8b9835d52f08f21ff>
# <N731e6834f4604048a308da7e41318202> a owl:Restriction ;
# 	owl:onProperty uml:durationObservationValue ;
# 	owl:allValuesFrom sbol:Identified.
# <N84b1d3a8df984f54ab34640a6cfb15dc> a owl:Restriction ;
# 	owl:onProperty uml:durationObservationValue ;
# 	owl:minCardinality <1>.
# <N3ea29d642ad84d2a9cf73ba7624a8a81> a owl:Restriction ;
# 	owl:onProperty uml:durationObservationValue ;
# 	owl:maxCardinality <2>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationObservation
# 	Remove uml:DurationObservation rdfs:subClassOf <ub8bL243C5>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N731e6834f4604048a308da7e41318202>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N84b1d3a8df984f54ab34640a6cfb15dc>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N3ea29d642ad84d2a9cf73ba7624a8a81>
# <N817581b18cc64bb3bad5044218155fe5> a owl:Restriction ;
# 	owl:onProperty uml:durationSpecification ;
# 	owl:onClass uml:DurationInterval.
# <Nb6c75401f8d04adf9f7637560368425a> a owl:Restriction ;
# 	owl:onProperty uml:durationSpecification ;
# 	owl:maxCardinality <1>.
# <Nc0abddb844414949bcdd0cad27d82759> a owl:Restriction ;
# 	owl:onProperty uml:durationSpecification ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationConstraint
# 	Remove uml:DurationConstraint rdfs:subClassOf <ub8bL349C5>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <N817581b18cc64bb3bad5044218155fe5>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Nb6c75401f8d04adf9f7637560368425a>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Nc0abddb844414949bcdd0cad27d82759>
# <N0cf216ffacb24e188430024f3c5126cf> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL373C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N0cf216ffacb24e188430024f3c5126cf>
# <Nb0c11432b0184d04acd89d40ac2dc662> a owl:Restriction ;
# 	owl:onProperty uml:target ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub8bL664C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <Nb0c11432b0184d04acd89d40ac2dc662>
# <N5d1fb66a930e48ddbf0ae31c375d63c1> a owl:Restriction ;
# 	owl:onProperty paml:sampleDataValues ;
# 	owl:allValuesFrom xsd:string.
# <N63a4a86296c044e6a9631de579c38797> a owl:Restriction ;
# 	owl:onProperty paml:sampleDataValues ;
# 	owl:maxCardinality <1>.
# <N6003d3d3d2f2433cbb2fdf129c318d0c> a owl:Restriction ;
# 	owl:onProperty paml:sampleDataValues ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#SampleData
# 	Remove paml:SampleData rdfs:subClassOf <ub9bL435C29>
# 	http://bioprotocols.org/paml#SampleData rdfs:subClassOf <N5d1fb66a930e48ddbf0ae31c375d63c1>
# 	http://bioprotocols.org/paml#SampleData rdfs:subClassOf <N63a4a86296c044e6a9631de579c38797>
# 	http://bioprotocols.org/paml#SampleData rdfs:subClassOf <N6003d3d3d2f2433cbb2fdf129c318d0c>
# <N3f34159bd2424234922928e4544bf2c6> a owl:Restriction ;
# 	owl:onProperty paml:specification ;
# 	owl:allValuesFrom sbol:TopLevel.
# <Ne73c3cbcd5a74a5594f3f3f73e6eff36> a owl:Restriction ;
# 	owl:onProperty paml:specification ;
# 	owl:minCardinality <1>.
# <N865ee5b2c7664511807aac32fc5c021b> a owl:Restriction ;
# 	owl:onProperty paml:specification ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#Material
# 	Remove paml:Material rdfs:subClassOf <ub9bL156C5>
# 	http://bioprotocols.org/paml#Material rdfs:subClassOf <N3f34159bd2424234922928e4544bf2c6>
# 	http://bioprotocols.org/paml#Material rdfs:subClassOf <Ne73c3cbcd5a74a5594f3f3f73e6eff36>
# 	http://bioprotocols.org/paml#Material rdfs:subClassOf <N865ee5b2c7664511807aac32fc5c021b>
# <Nb871a4698446454888dbdc2161bd2c8c> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValueSpecification
# 	Remove uml:ValueSpecification rdfs:subClassOf <ub8bL83C20>
# 	http://bioprotocols.org/uml#ValueSpecification rdfs:subClassOf <Nb871a4698446454888dbdc2161bd2c8c>
# <N3e2b88b9dfce47539b0fd559f0d90dfb> a owl:Restriction ;
# 	owl:onProperty uml:direction ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL367C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N3e2b88b9dfce47539b0fd559f0d90dfb>
# <Nc15ab8e275654cd297b56b111329c2c8> a owl:Restriction ;
# 	owl:onProperty uml:timeSpecification ;
# 	owl:minCardinality <1>.
# <N4ddf6a9e61b1424cb50ca1f4918e1a29> a owl:Restriction ;
# 	owl:onProperty uml:timeSpecification ;
# 	owl:maxCardinality <1>.
# <Na9edf0b6a9dc49cdb8d9e8fd7e5f5493> a owl:Restriction ;
# 	owl:onProperty uml:timeSpecification ;
# 	owl:onClass uml:TimeInterval.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeConstraint
# 	Remove uml:TimeConstraint rdfs:subClassOf <ub8bL334C5>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <Nc15ab8e275654cd297b56b111329c2c8>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N4ddf6a9e61b1424cb50ca1f4918e1a29>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <Na9edf0b6a9dc49cdb8d9e8fd7e5f5493>
# <Nead15f19100a4d1783dab71c629170c3> a owl:Restriction ;
# 	owl:onProperty uml:realValue ;
# 	owl:allValuesFrom xsd:float.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReal
# 	Remove uml:LiteralReal rdfs:subClassOf <ub8bL137C9>
# 	http://bioprotocols.org/uml#LiteralReal rdfs:subClassOf <Nead15f19100a4d1783dab71c629170c3>
# <N4d2b0384dbfc4fbc93101ff6ccf6908a> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL622C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N4d2b0384dbfc4fbc93101ff6ccf6908a>
# <N0384b0f7f78b473faec12276ae0ed6dd> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL377C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N0384b0f7f78b473faec12276ae0ed6dd>
# <N10d1349c978e4ef6bf8b1608ae2a5c58> a owl:Restriction ;
# 	owl:onProperty uml:stringValue ;
# 	owl:allValuesFrom xsd:string.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralString
# 	Remove uml:LiteralString rdfs:subClassOf <ub8bL98C5>
# 	http://bioprotocols.org/uml#LiteralString rdfs:subClassOf <N10d1349c978e4ef6bf8b1608ae2a5c58>
# <N2839a774422e406c9205c8f599fc0cf9> a owl:Restriction ;
# 	owl:onProperty uml:integerValue ;
# 	owl:allValuesFrom xsd:integer.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralInteger
# 	Remove uml:LiteralInteger rdfs:subClassOf <ub8bL111C9>
# 	http://bioprotocols.org/uml#LiteralInteger rdfs:subClassOf <N2839a774422e406c9205c8f599fc0cf9>
# <Nb396b0477ed34a42b7a991ddaeddb459> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL375C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Nb396b0477ed34a42b7a991ddaeddb459>
# <Nfef6e80607e24dcf940ba3d9c3af9cd2> a owl:Restriction ;
# 	owl:onProperty uml:ownedParameter ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Behavior
# 	Remove uml:Behavior rdfs:subClassOf <ub8bL407C5>
# 	http://bioprotocols.org/uml#Behavior rdfs:subClassOf <Nfef6e80607e24dcf940ba3d9c3af9cd2>
# <N276020bf829f46beb7294d34b5f85632> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL381C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N276020bf829f46beb7294d34b5f85632>
# <Ncec695a6157f4e158727b0ba55eaa541> a owl:Restriction ;
# 	owl:onProperty uml:referenceValue ;
# 	owl:allValuesFrom sbol:Identified.
# <N8b6248d3be4d43d99853c42d736bd2d6> a owl:Restriction ;
# 	owl:onProperty uml:referenceValue ;
# 	owl:minCardinality <1>.
# <Nb08936a74b054b6f838b7fae5b0dd8f7> a owl:Restriction ;
# 	owl:onProperty uml:referenceValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReference
# 	Remove uml:LiteralReference rdfs:subClassOf <ub8bL164C5>
# 	http://bioprotocols.org/uml#LiteralReference rdfs:subClassOf <Ncec695a6157f4e158727b0ba55eaa541>
# 	http://bioprotocols.org/uml#LiteralReference rdfs:subClassOf <N8b6248d3be4d43d99853c42d736bd2d6>
# 	http://bioprotocols.org/uml#LiteralReference rdfs:subClassOf <Nb08936a74b054b6f838b7fae5b0dd8f7>
# <N58ee2d5e0aa049c889f09dd35a1a1ebc> a owl:Restriction ;
# 	owl:onProperty uml:direction ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL368C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N58ee2d5e0aa049c889f09dd35a1a1ebc>
# <N3cd39a19556f4d86a91d7da2c143c57c> a owl:Restriction ;
# 	owl:onProperty uml:behavior ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#CallBehaviorAction
# 	Remove uml:CallBehaviorAction rdfs:subClassOf <ub8bL607C9>
# 	http://bioprotocols.org/uml#CallBehaviorAction rdfs:subClassOf <N3cd39a19556f4d86a91d7da2c143c57c>
# <N513062d35bbd43f6aaea94fd19d9a35c> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL626C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N513062d35bbd43f6aaea94fd19d9a35c>
# <Nc591fb9d0c5f400fa4d53dd0043960c0> a owl:Restriction ;
# 	owl:onProperty uml:identifiedValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralIdentified
# 	Remove uml:LiteralIdentified rdfs:subClassOf <ub8bL152C9>
# 	http://bioprotocols.org/uml#LiteralIdentified rdfs:subClassOf <Nc591fb9d0c5f400fa4d53dd0043960c0>
# <N2ce58971935846bb818f768735312a64> a owl:Restriction ;
# 	owl:onProperty uml:defaultValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL369C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N2ce58971935846bb818f768735312a64>
# <N66dc26867da84afaa3102425ff349b5b> a owl:Restriction ;
# 	owl:onProperty uml:identifiedValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralIdentified
# 	Remove uml:LiteralIdentified rdfs:subClassOf <ub8bL151C9>
# 	http://bioprotocols.org/uml#LiteralIdentified rdfs:subClassOf <N66dc26867da84afaa3102425ff349b5b>
# <N1f9ca32bcf044ad0aae201b81d2d28c4> a owl:Restriction ;
# 	owl:onProperty uml:booleanValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralBoolean
# 	Remove uml:LiteralBoolean rdfs:subClassOf <ub8bL126C9>
# 	http://bioprotocols.org/uml#LiteralBoolean rdfs:subClassOf <N1f9ca32bcf044ad0aae201b81d2d28c4>
# <N24954636297c4a2289b79777b189f51b> a owl:Restriction ;
# 	owl:onProperty uml:integerValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralInteger
# 	Remove uml:LiteralInteger rdfs:subClassOf <ub8bL113C9>
# 	http://bioprotocols.org/uml#LiteralInteger rdfs:subClassOf <N24954636297c4a2289b79777b189f51b>
# <N53a5e3607eec45d790df6135b2843fc7> a owl:Restriction ;
# 	owl:onProperty uml:observationValue ;
# 	owl:allValuesFrom uml:Observation.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Duration
# 	Remove uml:Duration rdfs:subClassOf <ub8bL207C5>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <N53a5e3607eec45d790df6135b2843fc7>
# <Nf36b93a5a6b24d8787aae08dadd75f19> a owl:Restriction ;
# 	owl:onProperty uml:minTimeValue ;
# 	owl:minCardinality <1>.
# <N8fd737f7bf894eac9ba0a7610bcf471e> a owl:Restriction ;
# 	owl:onProperty uml:minTimeValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <Nffc219ef668942719d29e31fcec60822> a owl:Restriction ;
# 	owl:onProperty uml:minTimeValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeInterval
# 	Remove uml:TimeInterval rdfs:subClassOf <ub8bL274C5>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <Nf36b93a5a6b24d8787aae08dadd75f19>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N8fd737f7bf894eac9ba0a7610bcf471e>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <Nffc219ef668942719d29e31fcec60822>
# <N53f3179d013b4f2c9ce52878bdc99a45> a owl:Restriction ;
# 	owl:onProperty uml:booleanValue ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralBoolean
# 	Remove uml:LiteralBoolean rdfs:subClassOf <ub8bL124C9>
# 	http://bioprotocols.org/uml#LiteralBoolean rdfs:subClassOf <N53f3179d013b4f2c9ce52878bdc99a45>
# <Nc477dee5e9f64f59b035a8ad9088cd18> a owl:Restriction ;
# 	owl:onProperty uml:realValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReal
# 	Remove uml:LiteralReal rdfs:subClassOf <ub8bL139C9>
# 	http://bioprotocols.org/uml#LiteralReal rdfs:subClassOf <Nc477dee5e9f64f59b035a8ad9088cd18>
# <N231aa3b7c6984a99a7413fd38f8d5984> a owl:Restriction ;
# 	owl:onProperty paml:prefixMap ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ContainerSpec
# 	Remove paml:ContainerSpec rdfs:subClassOf <ub9bL496C5>
# 	http://bioprotocols.org/paml#ContainerSpec rdfs:subClassOf <N231aa3b7c6984a99a7413fd38f8d5984>
# <N0f81415a2b2641bda9fd513d311952ce> a owl:Restriction ;
# 	owl:onProperty uml:decisionInputFlow ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub8bL520C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <N0f81415a2b2641bda9fd513d311952ce>
# <N2a638cbfd78d40058cc954c4e8dca177> a owl:Restriction ;
# 	owl:onProperty paml:parameterValuePair ;
# 	owl:allValuesFrom paml:ParameterValue.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#BehaviorExecution
# 	Remove paml:BehaviorExecution rdfs:subClassOf <ub9bL78C5>
# 	http://bioprotocols.org/paml#BehaviorExecution rdfs:subClassOf <N2a638cbfd78d40058cc954c4e8dca177>
# <N3cfc787426a94657819bd8fc79348771> a owl:Restriction ;
# 	owl:onProperty uml:output ;
# 	owl:allValuesFrom uml:OutputPin.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Action
# 	Remove uml:Action rdfs:subClassOf <ub8bL570C5>
# 	http://bioprotocols.org/uml#Action rdfs:subClassOf <N3cfc787426a94657819bd8fc79348771>
# <Nc010a7b1af94473a895ee8db0b550c61> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL382C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Nc010a7b1af94473a895ee8db0b550c61>
# <N88a6fc37c71c4cdb89fbd8210ccdd620> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <1>.
# <N3b28c9eafba74e1a8def27fa038b77a9> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# <N9db4a95edc664983aac00b0d42204b05> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <0>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeConstraint
# 	Remove uml:TimeConstraint rdfs:subClassOf <ub8bL336C5>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N88a6fc37c71c4cdb89fbd8210ccdd620>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N3b28c9eafba74e1a8def27fa038b77a9>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N9db4a95edc664983aac00b0d42204b05>
# <N3e911c50a6214bae9a0daa54ab239341> a owl:Restriction ;
# 	owl:onProperty paml:contents ;
# 	owl:minCardinality <1>
# 	rdfs:comment <N-dimensional array of URI for specification or nulls> .
# <N728715273fa54f2aba955138adffdd4d> a owl:Restriction ;
# 	owl:onProperty paml:contents ;
# 	owl:maxCardinality <1>
# 	rdfs:comment <N-dimensional array of URI for specification or nulls> .
# <N894f5b0b0acf42c38c3d168052a07413> a owl:Restriction ;
# 	owl:onProperty paml:contents ;
# 	owl:allValuesFrom xsd:string
# 	rdfs:comment <N-dimensional array of URI for specification or nulls> .
# Children of this restriction are:
# 	http://bioprotocols.org/paml#SampleArray
# 	Remove paml:SampleArray rdfs:subClassOf <ub9bL361C13>
# 	http://bioprotocols.org/paml#SampleArray rdfs:subClassOf <N3e911c50a6214bae9a0daa54ab239341>
# 	http://bioprotocols.org/paml#SampleArray rdfs:subClassOf <N728715273fa54f2aba955138adffdd4d>
# 	http://bioprotocols.org/paml#SampleArray rdfs:subClassOf <N894f5b0b0acf42c38c3d168052a07413>
# <N096d5194013447c889c85497d799dc17> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL629C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N096d5194013447c889c85497d799dc17>
# <N219cc40248464a99a209948587b41f2b> a owl:Restriction ;
# 	owl:onProperty uml:defaultValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL370C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N219cc40248464a99a209948587b41f2b>
# <N09ff9adecbe74252940dfc7f848bbfd6> a owl:Restriction ;
# 	owl:onProperty uml:postcondition ;
# 	owl:allValuesFrom uml:Constraint.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Behavior
# 	Remove uml:Behavior rdfs:subClassOf <ub8bL406C5>
# 	http://bioprotocols.org/uml#Behavior rdfs:subClassOf <N09ff9adecbe74252940dfc7f848bbfd6>
# <Nd788c0847ad6490b917687b6c6bc9165> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL374C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Nd788c0847ad6490b917687b6c6bc9165>
# <Nea34067d7e534f1892241697805907e3> a owl:Restriction ;
# 	owl:onProperty paml:source ;
# 	owl:maxCardinality <1>.
# <Nd6bdb957d9dd4514ae971be16889f5cb> a owl:Restriction ;
# 	owl:onProperty paml:source ;
# 	owl:minCardinality <1>.
# <Nc1fe5f0ec418435b8e59d367b38a6fb0> a owl:Restriction ;
# 	owl:onProperty paml:source ;
# 	owl:allValuesFrom paml:SampleCollection.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#SampleMask
# 	Remove paml:SampleMask rdfs:subClassOf <ub9bL393C13>
# 	http://bioprotocols.org/paml#SampleMask rdfs:subClassOf <Nea34067d7e534f1892241697805907e3>
# 	http://bioprotocols.org/paml#SampleMask rdfs:subClassOf <Nd6bdb957d9dd4514ae971be16889f5cb>
# 	http://bioprotocols.org/paml#SampleMask rdfs:subClassOf <Nc1fe5f0ec418435b8e59d367b38a6fb0>
# <N2846e7c872ea4dbca946a3df08760d3a> a owl:Restriction ;
# 	owl:onProperty uml:stringValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralString
# 	Remove uml:LiteralString rdfs:subClassOf <ub8bL100C5>
# 	http://bioprotocols.org/uml#LiteralString rdfs:subClassOf <N2846e7c872ea4dbca946a3df08760d3a>
# <Nb2652513e434421c9bbbed0bb9aef6be> a owl:Restriction ;
# 	owl:onProperty uml:input ;
# 	owl:allValuesFrom uml:InputPin.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Action
# 	Remove uml:Action rdfs:subClassOf <ub8bL569C5>
# 	http://bioprotocols.org/uml#Action rdfs:subClassOf <Nb2652513e434421c9bbbed0bb9aef6be>
# <Nc2068ab9995c47a580dd5bf4aa35fe18> a owl:Restriction ;
# 	owl:onProperty paml:parameter ;
# 	owl:minCardinality <1>.
# <N89363d012a96410d90da2eafc29379e8> a owl:Restriction ;
# 	owl:onProperty paml:parameter ;
# 	owl:maxCardinality <1>.
# <Nce3a3633b1c949e1adc99f7b1b2d5e33> a owl:Restriction ;
# 	owl:onProperty paml:parameter ;
# 	owl:allValuesFrom uml:Parameter.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ParameterValue
# 	Remove paml:ParameterValue rdfs:subClassOf <ub9bL128C5>
# 	http://bioprotocols.org/paml#ParameterValue rdfs:subClassOf <Nc2068ab9995c47a580dd5bf4aa35fe18>
# 	http://bioprotocols.org/paml#ParameterValue rdfs:subClassOf <N89363d012a96410d90da2eafc29379e8>
# 	http://bioprotocols.org/paml#ParameterValue rdfs:subClassOf <Nce3a3633b1c949e1adc99f7b1b2d5e33>
# <N512f33cdd28b42cba8d93d948d558aed> a owl:Restriction ;
# 	owl:onProperty paml:flow ;
# 	owl:allValuesFrom paml:ActivityEdgeFlow.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ProtocolExecution
# 	Remove paml:ProtocolExecution rdfs:subClassOf <ub9bL190C5>
# 	http://bioprotocols.org/paml#ProtocolExecution rdfs:subClassOf <N512f33cdd28b42cba8d93d948d558aed>
# <N713166c8c5d64819849e94cb419f33d4> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL620C14>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N713166c8c5d64819849e94cb419f33d4>
# <N580d02316cb6421a953707583f6fdf7e> a owl:Restriction ;
# 	owl:onProperty uml:behavior ;
# 	owl:allValuesFrom uml:Behavior.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#CallBehaviorAction
# 	Remove uml:CallBehaviorAction rdfs:subClassOf <ub8bL606C9>
# 	http://bioprotocols.org/uml#CallBehaviorAction rdfs:subClassOf <N580d02316cb6421a953707583f6fdf7e>
# <N039e8ea533144bfcaa58bfd2361a5abe> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:minCardinality <0>.
# <Ne3ac2bd2df004be2b4134553f4a8268c> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <N1bc40c0f7fad4b44b154a6cae90a1b65> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeExpression
# 	Remove uml:TimeExpression rdfs:subClassOf <ub8bL198C5>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <N039e8ea533144bfcaa58bfd2361a5abe>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <Ne3ac2bd2df004be2b4134553f4a8268c>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <N1bc40c0f7fad4b44b154a6cae90a1b65>
# <Na28d64667b844a418acb54a20affe413> a owl:Restriction ;
# 	owl:onProperty paml:call ;
# 	owl:maxCardinality <1>.
# <N938f9d9b5b3d409c93a71c6827e15fb8> a owl:Restriction ;
# 	owl:onProperty paml:call ;
# 	owl:minCardinality <1>.
# <Nceb95d6278b842e5bb18db6fc103e97a> a owl:Restriction ;
# 	owl:onProperty paml:call ;
# 	owl:allValuesFrom paml:BehaviorExecution.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#CallBehaviorExecution
# 	Remove paml:CallBehaviorExecution rdfs:subClassOf <ub9bL297C5>
# 	http://bioprotocols.org/paml#CallBehaviorExecution rdfs:subClassOf <Na28d64667b844a418acb54a20affe413>
# 	http://bioprotocols.org/paml#CallBehaviorExecution rdfs:subClassOf <N938f9d9b5b3d409c93a71c6827e15fb8>
# 	http://bioprotocols.org/paml#CallBehaviorExecution rdfs:subClassOf <Nceb95d6278b842e5bb18db6fc103e97a>
# <N5549925d915645fd9f4e38cca597f439> a owl:Restriction ;
# 	owl:onProperty paml:amount ;
# 	owl:allValuesFrom om:Measure.
# <N412c80fda87a405d824a0b3a6ba1b4cf> a owl:Restriction ;
# 	owl:onProperty paml:amount ;
# 	owl:minCardinality <1>.
# <N60aae5af55e74c029dd0e49ac2f8edf6> a owl:Restriction ;
# 	owl:onProperty paml:amount ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#Material
# 	Remove paml:Material rdfs:subClassOf <ub9bL158C5>
# 	http://bioprotocols.org/paml#Material rdfs:subClassOf <N5549925d915645fd9f4e38cca597f439>
# 	http://bioprotocols.org/paml#Material rdfs:subClassOf <N412c80fda87a405d824a0b3a6ba1b4cf>
# 	http://bioprotocols.org/paml#Material rdfs:subClassOf <N60aae5af55e74c029dd0e49ac2f8edf6>
# <Ne23665fdd7d84fcebfe2bbf350895df6> a owl:Restriction ;
# 	owl:onProperty uml:propertyValue ;
# 	owl:allValuesFrom sbol:Identified.
# <N232da66c936f497a894d1cc4ae97260b> a owl:Restriction ;
# 	owl:onProperty uml:propertyValue ;
# 	owl:minCardinality <1>.
# <N7e95d3ab65ee47599f6638c4f4018719> a owl:Restriction ;
# 	owl:onProperty uml:propertyValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#OrderedPropertyValue
# 	Remove uml:OrderedPropertyValue rdfs:subClassOf <ub8bL441C5>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Ne23665fdd7d84fcebfe2bbf350895df6>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <N232da66c936f497a894d1cc4ae97260b>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <N7e95d3ab65ee47599f6638c4f4018719>
# <N3d6ae2018a2642a5ab29faa756b9323a> a owl:Restriction ;
# 	owl:onProperty uml:decisionInputFlow ;
# 	owl:allValuesFrom uml:ObjectFlow.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub8bL519C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <N3d6ae2018a2642a5ab29faa756b9323a>
# <N8ec2d996801b474e8c3503e3e727d916> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL624C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N8ec2d996801b474e8c3503e3e727d916>
# <N4a859c73d77f4588b0826b2aad67ae88> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ObjectNode
# 	Remove uml:ObjectNode rdfs:subClassOf <ub8bL541C9>
# 	http://bioprotocols.org/uml#ObjectNode rdfs:subClassOf <N4a859c73d77f4588b0826b2aad67ae88>
# <N4828746cef5f42f592041b7a61e9f9e6> a owl:Restriction ;
# 	owl:onProperty uml:target ;
# 	owl:allValuesFrom uml:ActivityNode.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub8bL663C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <N4828746cef5f42f592041b7a61e9f9e6>
# <N710525516f584d45b8dcc3c11e7584b3> a owl:Restriction ;
# 	owl:onProperty uml:behavior ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#CallBehaviorAction
# 	Remove uml:CallBehaviorAction rdfs:subClassOf <ub8bL608C9>
# 	http://bioprotocols.org/uml#CallBehaviorAction rdfs:subClassOf <N710525516f584d45b8dcc3c11e7584b3>
# <N6c6aa2d3f8624d47b96007cafa0e2a2b> a owl:Restriction ;
# 	owl:onProperty uml:source ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub8bL661C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <N6c6aa2d3f8624d47b96007cafa0e2a2b>
# <N344a59ff85f24bb9b2a9c1b63e2ab879> a owl:Restriction ;
# 	owl:onProperty uml:value ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValuePin
# 	Remove uml:ValuePin rdfs:subClassOf <ub8bL641C5>
# 	http://bioprotocols.org/uml#ValuePin rdfs:subClassOf <N344a59ff85f24bb9b2a9c1b63e2ab879>
# <Ndeb63a18517343059ae6b5afe5879b1d> a owl:Restriction ;
# 	owl:onProperty paml:edge ;
# 	owl:minCardinality <0>.
# <Nf9628ef64bce477fafc896ff32307ba0> a owl:Restriction ;
# 	owl:onProperty paml:edge ;
# 	owl:maxCardinality <1>.
# <N83e9684b00454dc09e4e72ad9b9dc482> a owl:Restriction ;
# 	owl:onProperty paml:edge ;
# 	owl:allValuesFrom uml:ActivityEdge.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ActivityEdgeFlow
# 	Remove paml:ActivityEdgeFlow rdfs:subClassOf <ub9bL231C5>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <Ndeb63a18517343059ae6b5afe5879b1d>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <Nf9628ef64bce477fafc896ff32307ba0>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <N83e9684b00454dc09e4e72ad9b9dc482>
# <N6b82c1fd256b46849a4d85544c125c69> a owl:Restriction ;
# 	owl:onProperty uml:source ;
# 	owl:allValuesFrom uml:ActivityNode.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub8bL660C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <N6b82c1fd256b46849a4d85544c125c69>
# <Nb857e6bc4db241d9b00409e1dd902313> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <2>.
# <N38e571d6fa8b4219811f9aa822fad2f4> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <0>.
# <Neda80cfc2fcc4884ba056e6e634fdd11> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationObservation
# 	Remove uml:DurationObservation rdfs:subClassOf <ub8bL240C5>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <Nb857e6bc4db241d9b00409e1dd902313>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N38e571d6fa8b4219811f9aa822fad2f4>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <Neda80cfc2fcc4884ba056e6e634fdd11>
# <N928ca7d9d1df45329e6c59df8c56eca3> a owl:Restriction ;
# 	owl:onProperty uml:maxTimeValue ;
# 	owl:minCardinality <1>.
# <N94641d464af5434c91302988b547fb23> a owl:Restriction ;
# 	owl:onProperty uml:maxTimeValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <N6f7ac7f4ef5b4ac984b86cd082df951b> a owl:Restriction ;
# 	owl:onProperty uml:maxTimeValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeInterval
# 	Remove uml:TimeInterval rdfs:subClassOf <ub8bL276C5>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N928ca7d9d1df45329e6c59df8c56eca3>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N94641d464af5434c91302988b547fb23>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N6f7ac7f4ef5b4ac984b86cd082df951b>
# <N9c9e7d290d344f32b188acef7b377627> a owl:Restriction ;
# 	owl:onProperty paml:completedNormally ;
# 	owl:maxCardinality <1>.
# <Ncd649c90db9e43ad8b45cd5c595f1bb2> a owl:Restriction ;
# 	owl:onProperty paml:completedNormally ;
# 	owl:minCardinality <1>.
# <Ndde3d5e9300845269b83a86b29512f20> a owl:Restriction ;
# 	owl:onProperty paml:completedNormally ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#BehaviorExecution
# 	Remove paml:BehaviorExecution rdfs:subClassOf <ub9bL79C5>
# 	http://bioprotocols.org/paml#BehaviorExecution rdfs:subClassOf <N9c9e7d290d344f32b188acef7b377627>
# 	http://bioprotocols.org/paml#BehaviorExecution rdfs:subClassOf <Ncd649c90db9e43ad8b45cd5c595f1bb2>
# 	http://bioprotocols.org/paml#BehaviorExecution rdfs:subClassOf <Ndde3d5e9300845269b83a86b29512f20>
# <N09a8bad45d9d4bc59987ebb26a1e8283> a owl:Restriction ;
# 	owl:onProperty paml:consumedMaterial ;
# 	owl:allValuesFrom paml:Material.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#BehaviorExecution
# 	Remove paml:BehaviorExecution rdfs:subClassOf <ub9bL81C5>
# 	http://bioprotocols.org/paml#BehaviorExecution rdfs:subClassOf <N09a8bad45d9d4bc59987ebb26a1e8283>
# <N86e48f9cce2b433297ade0eb8a2bf3eb> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ObjectNode
# 	Remove uml:ObjectNode rdfs:subClassOf <ub8bL542C9>
# 	http://bioprotocols.org/uml#ObjectNode rdfs:subClassOf <N86e48f9cce2b433297ade0eb8a2bf3eb>
# <N8ab15d96490541d385e1166932a708d4> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <0>.
# <Ncc57da3e62064757b80cf18b73ee8b11> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <2>.
# <Nfedde5fdef7c4b9bbaf449512293657a> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationConstraint
# 	Remove uml:DurationConstraint rdfs:subClassOf <ub8bL351C5>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <N8ab15d96490541d385e1166932a708d4>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Ncc57da3e62064757b80cf18b73ee8b11>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Nfedde5fdef7c4b9bbaf449512293657a>
# <Nef6ce44099724090900c595cbcd54f73> a owl:Restriction ;
# 	owl:onProperty uml:stringValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralString
# 	Remove uml:LiteralString rdfs:subClassOf <ub8bL99C5>
# 	http://bioprotocols.org/uml#LiteralString rdfs:subClassOf <Nef6ce44099724090900c595cbcd54f73>
# <Nde89df05f29e4c07990d8f3107756323> a owl:Restriction ;
# 	owl:onProperty uml:symbolValue ;
# 	owl:allValuesFrom xsd:string.
# <Nb3435fdbae4e4c3183f1e744a43a8d08> a owl:Restriction ;
# 	owl:onProperty uml:symbolValue ;
# 	owl:maxCardinality <1>.
# <N98e78fbf71834f1ebb587130cfb2d7ad> a owl:Restriction ;
# 	owl:onProperty uml:symbolValue ;
# 	owl:minCardinality <0>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Expression
# 	Remove uml:Expression rdfs:subClassOf <ub8bL176C5>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <Nde89df05f29e4c07990d8f3107756323>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <Nb3435fdbae4e4c3183f1e744a43a8d08>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N98e78fbf71834f1ebb587130cfb2d7ad>
# <N247a597c03734f019b6b85f79a1194ea> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL627C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N247a597c03734f019b6b85f79a1194ea>
# <N9aa34d8f8a604c8faee05a7bf904c1fc> a owl:Restriction ;
# 	owl:onProperty uml:realValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReal
# 	Remove uml:LiteralReal rdfs:subClassOf <ub8bL138C9>
# 	http://bioprotocols.org/uml#LiteralReal rdfs:subClassOf <N9aa34d8f8a604c8faee05a7bf904c1fc>
# <N250e40fdbaa34c65b68a25d9f713c167> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValueSpecification
# 	Remove uml:ValueSpecification rdfs:subClassOf <ub8bL84C20>
# 	http://bioprotocols.org/uml#ValueSpecification rdfs:subClassOf <N250e40fdbaa34c65b68a25d9f713c167>
# <Nd7949746a5d247279febdbf0265ac59d> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL625C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Nd7949746a5d247279febdbf0265ac59d>
# <N398a4b10e57a43fd9d0e121f458d90eb> a owl:Restriction ;
# 	owl:onProperty uml:minDurationValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <Nf0aeaa77f37f421381dd255c26688a2f> a owl:Restriction ;
# 	owl:onProperty uml:minDurationValue ;
# 	owl:maxCardinality <1>.
# <Na8db0af56d814b119b500bed9d176654> a owl:Restriction ;
# 	owl:onProperty uml:minDurationValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationInterval
# 	Remove uml:DurationInterval rdfs:subClassOf <ub8bL296C5>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <N398a4b10e57a43fd9d0e121f458d90eb>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <Nf0aeaa77f37f421381dd255c26688a2f>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <Na8db0af56d814b119b500bed9d176654>
# <N4bee73021d334176a03ff8b7935eb8d3> a owl:Restriction ;
# 	owl:onProperty uml:observationValue ;
# 	owl:allValuesFrom uml:Observation.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeExpression
# 	Remove uml:TimeExpression rdfs:subClassOf <ub8bL200C5>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <N4bee73021d334176a03ff8b7935eb8d3>
# <N7aa7267ae4244bd69b299fe9c2d358bb> a owl:Restriction ;
# 	owl:onProperty uml:timeObservationValue ;
# 	owl:allValuesFrom sbol:Identified.
# <Nccf27e14c406433a820836a1de1fa8df> a owl:Restriction ;
# 	owl:onProperty uml:timeObservationValue ;
# 	owl:maxCardinality <1>.
# <N8157e8412518486fbd34a50c6bdfd3a9> a owl:Restriction ;
# 	owl:onProperty uml:timeObservationValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeObservation
# 	Remove uml:TimeObservation rdfs:subClassOf <ub8bL234C5>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N7aa7267ae4244bd69b299fe9c2d358bb>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Nccf27e14c406433a820836a1de1fa8df>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N8157e8412518486fbd34a50c6bdfd3a9>
# <Nea323337672b4f5e9a40e7ceffc57de5> a owl:Restriction ;
# 	owl:onProperty paml:edgeValue ;
# 	owl:maxCardinality <1>.
# <Nd73ed0df2b8147a39ff64466012c5964> a owl:Restriction ;
# 	owl:onProperty paml:edgeValue ;
# 	owl:allValuesFrom sbol:Identified.
# <N995769c4383a441bb0c0df6244254de7> a owl:Restriction ;
# 	owl:onProperty paml:edgeValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ActivityEdgeFlow
# 	Remove paml:ActivityEdgeFlow rdfs:subClassOf <ub9bL233C5>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <Nea323337672b4f5e9a40e7ceffc57de5>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <Nd73ed0df2b8147a39ff64466012c5964>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <N995769c4383a441bb0c0df6244254de7>
# <Nbd73338d88a84387a6d7d40a06a5f3f6> a owl:Restriction ;
# 	owl:onProperty paml:fromSamples ;
# 	owl:allValuesFrom paml:SampleCollection.
# <N927297fe7f3042f6805df121afe2644e> a owl:Restriction ;
# 	owl:onProperty paml:fromSamples ;
# 	owl:minCardinality <1>.
# <N3784b071c87e4e9c956367679f502c4c> a owl:Restriction ;
# 	owl:onProperty paml:fromSamples ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#SampleData
# 	Remove paml:SampleData rdfs:subClassOf <ub9bL441C29>
# 	http://bioprotocols.org/paml#SampleData rdfs:subClassOf <Nbd73338d88a84387a6d7d40a06a5f3f6>
# 	http://bioprotocols.org/paml#SampleData rdfs:subClassOf <N927297fe7f3042f6805df121afe2644e>
# 	http://bioprotocols.org/paml#SampleData rdfs:subClassOf <N3784b071c87e4e9c956367679f502c4c>
# <N2e0772f83d354a21b05e9d7509602a2d> a owl:Restriction ;
# 	owl:onProperty uml:maxDurationValue ;
# 	owl:minCardinality <1>.
# <N879b83f07d624c3a936466011943fffc> a owl:Restriction ;
# 	owl:onProperty uml:maxDurationValue ;
# 	owl:maxCardinality <1>.
# <Nb99648dfd71d4724a6554a9aa801f47c> a owl:Restriction ;
# 	owl:onProperty uml:maxDurationValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationInterval
# 	Remove uml:DurationInterval rdfs:subClassOf <ub8bL298C5>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <N2e0772f83d354a21b05e9d7509602a2d>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <N879b83f07d624c3a936466011943fffc>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <Nb99648dfd71d4724a6554a9aa801f47c>
# <Nb27379bae8a34154874c212ffdd5d69f> a owl:Restriction ;
# 	owl:onProperty paml:execution ;
# 	owl:allValuesFrom paml:ActivityNodeExecution.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ProtocolExecution
# 	Remove paml:ProtocolExecution rdfs:subClassOf <ub9bL189C5>
# 	http://bioprotocols.org/paml#ProtocolExecution rdfs:subClassOf <Nb27379bae8a34154874c212ffdd5d69f>
# <N7643afd52db9457eabf4009f73ba6602> a owl:Restriction ;
# 	owl:onProperty uml:direction ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL366C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N7643afd52db9457eabf4009f73ba6602>
# <Nfc4f08f36e75432a9cf8bbaf81d1fa0b> a owl:Restriction ;
# 	owl:onProperty uml:indexValue ;
# 	owl:minCardinality <1>.
# <Nec3b96c0a5ee4ba6855df6223f62003a> a owl:Restriction ;
# 	owl:onProperty uml:indexValue ;
# 	owl:allValuesFrom xsd:integer.
# <N1fbbdc18cdff4a57b5835b2ce4862c35> a owl:Restriction ;
# 	owl:onProperty uml:indexValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#OrderedPropertyValue
# 	Remove uml:OrderedPropertyValue rdfs:subClassOf <ub8bL439C5>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Nfc4f08f36e75432a9cf8bbaf81d1fa0b>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Nec3b96c0a5ee4ba6855df6223f62003a>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <N1fbbdc18cdff4a57b5835b2ce4862c35>
# <Nba3e1d07bafa41ddaafbcd8261a6974a> a owl:Restriction ;
# 	owl:onProperty uml:edge ;
# 	owl:allValuesFrom uml:ActivityEdge.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Activity
# 	Remove uml:Activity rdfs:subClassOf <ub8bL460C5>
# 	http://bioprotocols.org/uml#Activity rdfs:subClassOf <Nba3e1d07bafa41ddaafbcd8261a6974a>
# <N6067f39f6434495fa9a72bbe58a7f6cc> a owl:Restriction ;
# 	owl:onProperty uml:value ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValuePin
# 	Remove uml:ValuePin rdfs:subClassOf <ub8bL642C5>
# 	http://bioprotocols.org/uml#ValuePin rdfs:subClassOf <N6067f39f6434495fa9a72bbe58a7f6cc>
# <Na70d6ac538c94a78ac22c5912fe3b3b3> a owl:Restriction ;
# 	owl:onProperty paml:node ;
# 	owl:minCardinality <1>.
# <N269d41f42c1d403ca685d2b9434cad49> a owl:Restriction ;
# 	owl:onProperty paml:node ;
# 	owl:allValuesFrom uml:ActivityNode.
# <N1315918fb4c142bf9b14adb38e66da9f> a owl:Restriction ;
# 	owl:onProperty paml:node ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ActivityNodeExecution
# 	Remove paml:ActivityNodeExecution rdfs:subClassOf <ub9bL271C5>
# 	http://bioprotocols.org/paml#ActivityNodeExecution rdfs:subClassOf <Na70d6ac538c94a78ac22c5912fe3b3b3>
# 	http://bioprotocols.org/paml#ActivityNodeExecution rdfs:subClassOf <N269d41f42c1d403ca685d2b9434cad49>
# 	http://bioprotocols.org/paml#ActivityNodeExecution rdfs:subClassOf <N1315918fb4c142bf9b14adb38e66da9f>
# <Nbf35f43895f14c398c0c99f73db6608a> a owl:Restriction ;
# 	owl:onProperty paml:queryString ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ContainerSpec
# 	Remove paml:ContainerSpec rdfs:subClassOf <ub9bL487C5>
# 	http://bioprotocols.org/paml#ContainerSpec rdfs:subClassOf <Nbf35f43895f14c398c0c99f73db6608a>
# <Nc855c460c5b6441d99392253d768ae84> a owl:Restriction ;
# 	owl:onProperty paml:prefixMap ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ContainerSpec
# 	Remove paml:ContainerSpec rdfs:subClassOf <ub9bL493C5>
# 	http://bioprotocols.org/paml#ContainerSpec rdfs:subClassOf <Nc855c460c5b6441d99392253d768ae84>
# <N440106361ab642cba9ec57cd489d71a8> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL384C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N440106361ab642cba9ec57cd489d71a8>
# <N82ed66d1fa8a44b6954be4496153363a> a owl:Restriction ;
# 	owl:onProperty paml:mask ;
# 	owl:maxCardinality <1>.
# <N98a697d362bb43b580e4e7acf89db0ea> a owl:Restriction ;
# 	owl:onProperty paml:mask ;
# 	owl:minCardinality <1>.
# <N3934c18d269641a29e3c33130209ad0a> a owl:Restriction ;
# 	owl:onProperty paml:mask ;
# 	owl:allValuesFrom xsd:string.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#SampleMask
# 	Remove paml:SampleMask rdfs:subClassOf <ub9bL398C13>
# 	http://bioprotocols.org/paml#SampleMask rdfs:subClassOf <N82ed66d1fa8a44b6954be4496153363a>
# 	http://bioprotocols.org/paml#SampleMask rdfs:subClassOf <N98a697d362bb43b580e4e7acf89db0ea>
# 	http://bioprotocols.org/paml#SampleMask rdfs:subClassOf <N3934c18d269641a29e3c33130209ad0a>
# <N0307a99ae7b14df4bd7df711d542579a> a owl:Restriction ;
# 	owl:onProperty uml:node ;
# 	owl:allValuesFrom uml:ActivityNode.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Activity
# 	Remove uml:Activity rdfs:subClassOf <ub8bL459C5>
# 	http://bioprotocols.org/uml#Activity rdfs:subClassOf <N0307a99ae7b14df4bd7df711d542579a>
# <N10670f11d76c4d10b67adda301a5667a> a owl:Restriction ;
# 	owl:onProperty uml:booleanValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralBoolean
# 	Remove uml:LiteralBoolean rdfs:subClassOf <ub8bL125C9>
# 	http://bioprotocols.org/uml#LiteralBoolean rdfs:subClassOf <N10670f11d76c4d10b67adda301a5667a>
# <Nd5f8c10b56c74f33941b346132eb5a88> a owl:Restriction ;
# 	owl:onProperty uml:operandValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Expression
# 	Remove uml:Expression rdfs:subClassOf <ub8bL180C5>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <Nd5f8c10b56c74f33941b346132eb5a88>
# <N4816024cc77148da8e5bdb763fabdfa7> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL380C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N4816024cc77148da8e5bdb763fabdfa7>
# <N8d6eb4ea386e478a8962f0cd17eb9cd8> a owl:Restriction ;
# 	owl:onProperty uml:decisionInput ;
# 	owl:allValuesFrom uml:Behavior.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub8bL517C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <N8d6eb4ea386e478a8962f0cd17eb9cd8>
# <Nf935d33e31284d0a8cf2852ccfd5060d> a owl:Restriction ;
# 	owl:onProperty paml:tokenSource ;
# 	owl:minCardinality <1>.
# <N35dbe8a5300c4ac3978f935243bbaba6> a owl:Restriction ;
# 	owl:onProperty paml:tokenSource ;
# 	owl:maxCardinality <1>.
# <N0df6e572c652431bbdc13348b67499e1> a owl:Restriction ;
# 	owl:onProperty paml:tokenSource ;
# 	owl:allValuesFrom paml:ActivityNodeExecution.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ActivityEdgeFlow
# 	Remove paml:ActivityEdgeFlow rdfs:subClassOf <ub9bL235C5>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <Nf935d33e31284d0a8cf2852ccfd5060d>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <N35dbe8a5300c4ac3978f935243bbaba6>
# 	http://bioprotocols.org/paml#ActivityEdgeFlow rdfs:subClassOf <N0df6e572c652431bbdc13348b67499e1>
# <Nb6234afe512f4cd9862d9bcfd398d350> a owl:Restriction ;
# 	owl:onProperty uml:target ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub8bL665C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <Nb6234afe512f4cd9862d9bcfd398d350>
# <N12086e18c78e451db8e13de15932490c> a owl:Restriction ;
# 	owl:onProperty uml:identifiedValue ;
# 	owl:allValuesFrom sbol:Identified.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralIdentified
# 	Remove uml:LiteralIdentified rdfs:subClassOf <ub8bL150C9>
# 	http://bioprotocols.org/uml#LiteralIdentified rdfs:subClassOf <N12086e18c78e451db8e13de15932490c>
# <N38a0de7a82d14cf6b292d696b8720717> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL623C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N38a0de7a82d14cf6b292d696b8720717>
# <Ndca3b8d4f8c94511b0e8667965de909b> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL379C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Ndca3b8d4f8c94511b0e8667965de909b>
# <N2b8324f8f474453e82d48f8735d57c1e> a owl:Restriction ;
# 	owl:onProperty paml:protocol ;
# 	owl:minCardinality <1>.
# <Ne9c7b93d1e57448286a9354ef35ce09e> a owl:Restriction ;
# 	owl:onProperty paml:protocol ;
# 	owl:maxCardinality <1>.
# <Ned6f90aec4d141d0919b001fc76afafb> a owl:Restriction ;
# 	owl:onProperty paml:protocol ;
# 	owl:allValuesFrom paml:Protocol.
# Children of this restriction are:
# 	http://bioprotocols.org/paml#ProtocolExecution
# 	Remove paml:ProtocolExecution rdfs:subClassOf <ub9bL187C5>
# 	http://bioprotocols.org/paml#ProtocolExecution rdfs:subClassOf <N2b8324f8f474453e82d48f8735d57c1e>
# 	http://bioprotocols.org/paml#ProtocolExecution rdfs:subClassOf <Ne9c7b93d1e57448286a9354ef35ce09e>
# 	http://bioprotocols.org/paml#ProtocolExecution rdfs:subClassOf <Ned6f90aec4d141d0919b001fc76afafb>
# <N79224930ddb74bd48e4aef05cf69eca2> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <N7560161db1314916a7a27d8c7e1a0cc2> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:minCardinality <0>.
# <Nd104c865b1244d35bc549cce93e6f3e5> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Duration
# 	Remove uml:Duration rdfs:subClassOf <ub8bL205C5>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <N79224930ddb74bd48e4aef05cf69eca2>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <N7560161db1314916a7a27d8c7e1a0cc2>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <Nd104c865b1244d35bc549cce93e6f3e5>
# <Nd19ecc3914464baba2f951ff86189c25> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub8bL628C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Nd19ecc3914464baba2f951ff86189c25>
# <Ne899325c9f134f66b05aa4b8a1865c3e> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub8bL378C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Ne899325c9f134f66b05aa4b8a1865c3e>
# <Nbb9a17060f1b408bbaa540c1d265cadb> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:allValuesFrom xsd:boolean.
# <Nb555abbcd56f4264b3584e23c18f2da6> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:minCardinality <1>.
# <N9e3438a473974a4a9fb1674548c039b4> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Expression
# 	Remove uml:Expression rdfs:subClassOf <ub8bL178C5>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <Nbb9a17060f1b408bbaa540c1d265cadb>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <Nb555abbcd56f4264b3584e23c18f2da6>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N9e3438a473974a4a9fb1674548c039b4>
# <Nc8e27ac3014a48298af9c27dc19640b3> a owl:Restriction ;
# 	owl:onProperty uml:source ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub8bL662C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <Nc8e27ac3014a48298af9c27dc19640b3>
# <Graph identifier=N2029fcab25f848a2bbd4b39663c16a83 (<class 'rdflib.graph.Graph'>)>

# %%
g.serialize(destination='paml-original.nt')

# %%
new_g.serialize(destination='paml-revised.nt')

# %%
new_g.serialize(destination='paml-revised.ttl', format='turtle')

# %% [markdown]
# # Now fix the UML file

# %%
g = rdf.Graph().parse('../uml/uml.ttl', format='turtle')
g.serialize(destination='uml-original.nt')

# %%
q = """
    PREFIX owl: <%s>

    SELECT ?r
    {
        # ?r a owl:Restriction .
    }
"""%rdf.OWL


restrs = [r["r"] for r in g.query(q)]
restrs
# Out:
# [rdflib.term.BNode('ub10bL378C5'),
#  rdflib.term.BNode('ub10bL164C5'),
#  rdflib.term.BNode('ub10bL661C5'),
#  rdflib.term.BNode('ub10bL519C5'),
#  rdflib.term.BNode('ub10bL642C5'),
#  rdflib.term.BNode('ub10bL550C9'),
#  rdflib.term.BNode('ub10bL439C5'),
#  rdflib.term.BNode('ub10bL126C9'),
#  rdflib.term.BNode('ub10bL459C5'),
#  rdflib.term.BNode('ub10bL621C9'),
#  rdflib.term.BNode('ub10bL517C5'),
#  rdflib.term.BNode('ub10bL198C5'),
#  rdflib.term.BNode('ub10bL240C5'),
#  rdflib.term.BNode('ub10bL205C5'),
#  rdflib.term.BNode('ub10bL374C5'),
#  rdflib.term.BNode('ub10bL406C5'),
#  rdflib.term.BNode('ub10bL441C5'),
#  rdflib.term.BNode('ub10bL541C9'),
#  rdflib.term.BNode('ub10bL112C9'),
#  rdflib.term.BNode('ub10bL99C5'),
#  rdflib.term.BNode('ub10bL298C5'),
#  rdflib.term.BNode('ub10bL113C9'),
#  rdflib.term.BNode('ub10bL570C5'),
#  rdflib.term.BNode('ub10bL150C9'),
#  rdflib.term.BNode('ub10bL518C5'),
#  rdflib.term.BNode('ub10bL276C5'),
#  rdflib.term.BNode('ub10bL607C9'),
#  rdflib.term.BNode('ub10bL460C5'),
#  rdflib.term.BNode('ub10bL627C9'),
#  rdflib.term.BNode('ub10bL351C5'),
#  rdflib.term.BNode('ub10bL624C9'),
#  rdflib.term.BNode('ub10bL234C5'),
#  rdflib.term.BNode('ub10bL625C9'),
#  rdflib.term.BNode('ub10bL640C5'),
#  rdflib.term.BNode('ub10bL377C5'),
#  rdflib.term.BNode('ub10bL83C20'),
#  rdflib.term.BNode('ub10bL383C5'),
#  rdflib.term.BNode('ub10bL370C9'),
#  rdflib.term.BNode('ub10bL405C5'),
#  rdflib.term.BNode('ub10bL622C9'),
#  rdflib.term.BNode('ub10bL111C9'),
#  rdflib.term.BNode('ub10bL665C5'),
#  rdflib.term.BNode('ub10bL84C20'),
#  rdflib.term.BNode('ub10bL98C5'),
#  rdflib.term.BNode('ub10bL373C5'),
#  rdflib.term.BNode('ub10bL243C5'),
#  rdflib.term.BNode('ub10bL520C5'),
#  rdflib.term.BNode('ub10bL152C9'),
#  rdflib.term.BNode('ub10bL548C9'),
#  rdflib.term.BNode('ub10bL336C5'),
#  rdflib.term.BNode('ub10bL200C5'),
#  rdflib.term.BNode('ub10bL124C9'),
#  rdflib.term.BNode('ub10bL349C5'),
#  rdflib.term.BNode('ub10bL384C5'),
#  rdflib.term.BNode('ub10bL381C5'),
#  rdflib.term.BNode('ub10bL232C5'),
#  rdflib.term.BNode('ub10bL641C5'),
#  rdflib.term.BNode('ub10bL626C9'),
#  rdflib.term.BNode('ub10bL628C9'),
#  rdflib.term.BNode('ub10bL274C5'),
#  rdflib.term.BNode('ub10bL138C9'),
#  rdflib.term.BNode('ub10bL334C5'),
#  rdflib.term.BNode('ub10bL407C5'),
#  rdflib.term.BNode('ub10bL367C9'),
#  rdflib.term.BNode('ub10bL319C9'),
#  rdflib.term.BNode('ub10bL629C9'),
#  rdflib.term.BNode('ub10bL606C9'),
#  rdflib.term.BNode('ub10bL549C9'),
#  rdflib.term.BNode('ub10bL380C5'),
#  rdflib.term.BNode('ub10bL542C9'),
#  rdflib.term.BNode('ub10bL379C5'),
#  rdflib.term.BNode('ub10bL623C9'),
#  rdflib.term.BNode('ub10bL376C5'),
#  rdflib.term.BNode('ub10bL569C5'),
#  rdflib.term.BNode('ub10bL375C5'),
#  rdflib.term.BNode('ub10bL366C9'),
#  rdflib.term.BNode('ub10bL382C5'),
#  rdflib.term.BNode('ub10bL296C5'),
#  rdflib.term.BNode('ub10bL662C5'),
#  rdflib.term.BNode('ub10bL151C9'),
#  rdflib.term.BNode('ub10bL368C9'),
#  rdflib.term.BNode('ub10bL664C5'),
#  rdflib.term.BNode('ub10bL139C9'),
#  rdflib.term.BNode('ub10bL125C9'),
#  rdflib.term.BNode('ub10bL207C5'),
#  rdflib.term.BNode('ub10bL663C5'),
#  rdflib.term.BNode('ub10bL180C5'),
#  rdflib.term.BNode('ub10bL369C9'),
#  rdflib.term.BNode('ub10bL620C14'),
#  rdflib.term.BNode('ub10bL137C9'),
#  rdflib.term.BNode('ub10bL660C5'),
#  rdflib.term.BNode('ub10bL100C5'),
#  rdflib.term.BNode('ub10bL178C5'),
#  rdflib.term.BNode('ub10bL176C5'),
#  rdflib.term.BNode('ub10bL608C9')]

# %%
bad = [x for x in restrs if is_bad_restr(x, g)]
bad
# Out:
# [rdflib.term.BNode('ub10bL378C5'),
#  rdflib.term.BNode('ub10bL164C5'),
#  rdflib.term.BNode('ub10bL661C5'),
#  rdflib.term.BNode('ub10bL519C5'),
#  rdflib.term.BNode('ub10bL642C5'),
#  rdflib.term.BNode('ub10bL550C9'),
#  rdflib.term.BNode('ub10bL439C5'),
#  rdflib.term.BNode('ub10bL126C9'),
#  rdflib.term.BNode('ub10bL459C5'),
#  rdflib.term.BNode('ub10bL621C9'),
#  rdflib.term.BNode('ub10bL517C5'),
#  rdflib.term.BNode('ub10bL198C5'),
#  rdflib.term.BNode('ub10bL240C5'),
#  rdflib.term.BNode('ub10bL205C5'),
#  rdflib.term.BNode('ub10bL374C5'),
#  rdflib.term.BNode('ub10bL406C5'),
#  rdflib.term.BNode('ub10bL441C5'),
#  rdflib.term.BNode('ub10bL541C9'),
#  rdflib.term.BNode('ub10bL112C9'),
#  rdflib.term.BNode('ub10bL99C5'),
#  rdflib.term.BNode('ub10bL298C5'),
#  rdflib.term.BNode('ub10bL113C9'),
#  rdflib.term.BNode('ub10bL570C5'),
#  rdflib.term.BNode('ub10bL150C9'),
#  rdflib.term.BNode('ub10bL518C5'),
#  rdflib.term.BNode('ub10bL276C5'),
#  rdflib.term.BNode('ub10bL607C9'),
#  rdflib.term.BNode('ub10bL460C5'),
#  rdflib.term.BNode('ub10bL627C9'),
#  rdflib.term.BNode('ub10bL351C5'),
#  rdflib.term.BNode('ub10bL624C9'),
#  rdflib.term.BNode('ub10bL234C5'),
#  rdflib.term.BNode('ub10bL625C9'),
#  rdflib.term.BNode('ub10bL640C5'),
#  rdflib.term.BNode('ub10bL377C5'),
#  rdflib.term.BNode('ub10bL83C20'),
#  rdflib.term.BNode('ub10bL383C5'),
#  rdflib.term.BNode('ub10bL370C9'),
#  rdflib.term.BNode('ub10bL405C5'),
#  rdflib.term.BNode('ub10bL622C9'),
#  rdflib.term.BNode('ub10bL111C9'),
#  rdflib.term.BNode('ub10bL665C5'),
#  rdflib.term.BNode('ub10bL84C20'),
#  rdflib.term.BNode('ub10bL98C5'),
#  rdflib.term.BNode('ub10bL373C5'),
#  rdflib.term.BNode('ub10bL243C5'),
#  rdflib.term.BNode('ub10bL520C5'),
#  rdflib.term.BNode('ub10bL152C9'),
#  rdflib.term.BNode('ub10bL548C9'),
#  rdflib.term.BNode('ub10bL336C5'),
#  rdflib.term.BNode('ub10bL200C5'),
#  rdflib.term.BNode('ub10bL124C9'),
#  rdflib.term.BNode('ub10bL349C5'),
#  rdflib.term.BNode('ub10bL384C5'),
#  rdflib.term.BNode('ub10bL381C5'),
#  rdflib.term.BNode('ub10bL232C5'),
#  rdflib.term.BNode('ub10bL641C5'),
#  rdflib.term.BNode('ub10bL626C9'),
#  rdflib.term.BNode('ub10bL628C9'),
#  rdflib.term.BNode('ub10bL274C5'),
#  rdflib.term.BNode('ub10bL138C9'),
#  rdflib.term.BNode('ub10bL334C5'),
#  rdflib.term.BNode('ub10bL407C5'),
#  rdflib.term.BNode('ub10bL367C9'),
#  rdflib.term.BNode('ub10bL319C9'),
#  rdflib.term.BNode('ub10bL629C9'),
#  rdflib.term.BNode('ub10bL606C9'),
#  rdflib.term.BNode('ub10bL549C9'),
#  rdflib.term.BNode('ub10bL380C5'),
#  rdflib.term.BNode('ub10bL542C9'),
#  rdflib.term.BNode('ub10bL379C5'),
#  rdflib.term.BNode('ub10bL623C9'),
#  rdflib.term.BNode('ub10bL376C5'),
#  rdflib.term.BNode('ub10bL569C5'),
#  rdflib.term.BNode('ub10bL375C5'),
#  rdflib.term.BNode('ub10bL366C9'),
#  rdflib.term.BNode('ub10bL382C5'),
#  rdflib.term.BNode('ub10bL296C5'),
#  rdflib.term.BNode('ub10bL662C5'),
#  rdflib.term.BNode('ub10bL151C9'),
#  rdflib.term.BNode('ub10bL368C9'),
#  rdflib.term.BNode('ub10bL664C5'),
#  rdflib.term.BNode('ub10bL139C9'),
#  rdflib.term.BNode('ub10bL125C9'),
#  rdflib.term.BNode('ub10bL207C5'),
#  rdflib.term.BNode('ub10bL663C5'),
#  rdflib.term.BNode('ub10bL180C5'),
#  rdflib.term.BNode('ub10bL369C9'),
#  rdflib.term.BNode('ub10bL620C14'),
#  rdflib.term.BNode('ub10bL137C9'),
#  rdflib.term.BNode('ub10bL660C5'),
#  rdflib.term.BNode('ub10bL100C5'),
#  rdflib.term.BNode('ub10bL178C5'),
#  rdflib.term.BNode('ub10bL176C5'),
#  rdflib.term.BNode('ub10bL608C9')]

# %%
new_g = deepcopy(g)

repair_all_bad_restrictions(bad, new_g)
# Out:
# <Naf4c82bae83341e8ba473c94e418e685> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL378C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Naf4c82bae83341e8ba473c94e418e685>
# <Na556454fff23485098a4b26b8214f20c> a owl:Restriction ;
# 	owl:onProperty uml:referenceValue ;
# 	owl:allValuesFrom sbol:Identified.
# <Naf9f95a092ea47a282418765ec7c923b> a owl:Restriction ;
# 	owl:onProperty uml:referenceValue ;
# 	owl:minCardinality <1>.
# <N41e67d7b45c645cfab16d8093e27d107> a owl:Restriction ;
# 	owl:onProperty uml:referenceValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReference
# 	Remove uml:LiteralReference rdfs:subClassOf <ub10bL164C5>
# 	http://bioprotocols.org/uml#LiteralReference rdfs:subClassOf <Na556454fff23485098a4b26b8214f20c>
# 	http://bioprotocols.org/uml#LiteralReference rdfs:subClassOf <Naf9f95a092ea47a282418765ec7c923b>
# 	http://bioprotocols.org/uml#LiteralReference rdfs:subClassOf <N41e67d7b45c645cfab16d8093e27d107>
# <N9cb4f98a30f34ae8b48709cf9475f9c0> a owl:Restriction ;
# 	owl:onProperty uml:source ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub10bL661C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <N9cb4f98a30f34ae8b48709cf9475f9c0>
# <Ncd3175f056574b1b8cabc820fadaf5ff> a owl:Restriction ;
# 	owl:onProperty uml:decisionInputFlow ;
# 	owl:allValuesFrom uml:ObjectFlow.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub10bL519C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <Ncd3175f056574b1b8cabc820fadaf5ff>
# <N5691b58aae704c909a40b2d2305e4662> a owl:Restriction ;
# 	owl:onProperty uml:value ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValuePin
# 	Remove uml:ValuePin rdfs:subClassOf <ub10bL642C5>
# 	http://bioprotocols.org/uml#ValuePin rdfs:subClassOf <N5691b58aae704c909a40b2d2305e4662>
# <N70b9b8fa100e40b4a7a66f511cb0c89a> a owl:Restriction ;
# 	owl:onProperty uml:parameter ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityParameterNode
# 	Remove uml:ActivityParameterNode rdfs:subClassOf <ub10bL550C9>
# 	http://bioprotocols.org/uml#ActivityParameterNode rdfs:subClassOf <N70b9b8fa100e40b4a7a66f511cb0c89a>
# <Nedab98e740eb46a88679596d1284bb31> a owl:Restriction ;
# 	owl:onProperty uml:indexValue ;
# 	owl:allValuesFrom xsd:integer.
# <N656b6aaec4a64aa78ec8738f0c02a1a6> a owl:Restriction ;
# 	owl:onProperty uml:indexValue ;
# 	owl:maxCardinality <1>.
# <N6873c710c635475f859fd29d668f9994> a owl:Restriction ;
# 	owl:onProperty uml:indexValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#OrderedPropertyValue
# 	Remove uml:OrderedPropertyValue rdfs:subClassOf <ub10bL439C5>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Nedab98e740eb46a88679596d1284bb31>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <N656b6aaec4a64aa78ec8738f0c02a1a6>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <N6873c710c635475f859fd29d668f9994>
# <N71e34f1e2e1e4edc80e9f6caa328a8d8> a owl:Restriction ;
# 	owl:onProperty uml:booleanValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralBoolean
# 	Remove uml:LiteralBoolean rdfs:subClassOf <ub10bL126C9>
# 	http://bioprotocols.org/uml#LiteralBoolean rdfs:subClassOf <N71e34f1e2e1e4edc80e9f6caa328a8d8>
# <N9051a3719d36459ab0991e5a112de19b> a owl:Restriction ;
# 	owl:onProperty uml:node ;
# 	owl:allValuesFrom uml:ActivityNode.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Activity
# 	Remove uml:Activity rdfs:subClassOf <ub10bL459C5>
# 	http://bioprotocols.org/uml#Activity rdfs:subClassOf <N9051a3719d36459ab0991e5a112de19b>
# <Nc4e9dd29d42c411780c23605e1c5125e> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL621C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Nc4e9dd29d42c411780c23605e1c5125e>
# <N4a98d629e67a4d4da15349e1f19e315e> a owl:Restriction ;
# 	owl:onProperty uml:decisionInput ;
# 	owl:allValuesFrom uml:Behavior.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub10bL517C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <N4a98d629e67a4d4da15349e1f19e315e>
# <N5d4ab928d022455b92e013536cef2202> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <Nf98f7bbce48c4f5394cd8efe68dfaa9a> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:minCardinality <0>.
# <Nc622507402fc4de7a11472f242a518cf> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeExpression
# 	Remove uml:TimeExpression rdfs:subClassOf <ub10bL198C5>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <N5d4ab928d022455b92e013536cef2202>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <Nf98f7bbce48c4f5394cd8efe68dfaa9a>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <Nc622507402fc4de7a11472f242a518cf>
# <N6cfb9872408e48ebbcbc019e7d151570> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <0>.
# <N242bf6fd4ff44d4ba593fcf9072f6637> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <2>.
# <N39ba37204d2740b2a4e0e38a98272b27> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationObservation
# 	Remove uml:DurationObservation rdfs:subClassOf <ub10bL240C5>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N6cfb9872408e48ebbcbc019e7d151570>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N242bf6fd4ff44d4ba593fcf9072f6637>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <N39ba37204d2740b2a4e0e38a98272b27>
# <N5dc1e342e2314bcda4ecbb2b7d21a30a> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:maxCardinality <1>.
# <N403b61883d004cbbbdd8f0e31bdfe147> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <Nb9a4a8d22b224df3be21bc22910b34ad> a owl:Restriction ;
# 	owl:onProperty uml:exprValue ;
# 	owl:minCardinality <0>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Duration
# 	Remove uml:Duration rdfs:subClassOf <ub10bL205C5>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <N5dc1e342e2314bcda4ecbb2b7d21a30a>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <N403b61883d004cbbbdd8f0e31bdfe147>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <Nb9a4a8d22b224df3be21bc22910b34ad>
# <N508bdb9bafec456283c295bfe9a3fb0b> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL374C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N508bdb9bafec456283c295bfe9a3fb0b>
# <Nd549a0594e174189a2ca88ae7d2f431b> a owl:Restriction ;
# 	owl:onProperty uml:postcondition ;
# 	owl:allValuesFrom uml:Constraint.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Behavior
# 	Remove uml:Behavior rdfs:subClassOf <ub10bL406C5>
# 	http://bioprotocols.org/uml#Behavior rdfs:subClassOf <Nd549a0594e174189a2ca88ae7d2f431b>
# <Nbe68fdb00a504a90b497f923c3653588> a owl:Restriction ;
# 	owl:onProperty uml:propertyValue ;
# 	owl:maxCardinality <1>.
# <Ndfffca44585c4c1fb46302f876386084> a owl:Restriction ;
# 	owl:onProperty uml:propertyValue ;
# 	owl:allValuesFrom sbol:Identified.
# <Nfd1014361caf43e281b55bea9e37d926> a owl:Restriction ;
# 	owl:onProperty uml:propertyValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#OrderedPropertyValue
# 	Remove uml:OrderedPropertyValue rdfs:subClassOf <ub10bL441C5>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Nbe68fdb00a504a90b497f923c3653588>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Ndfffca44585c4c1fb46302f876386084>
# 	http://bioprotocols.org/uml#OrderedPropertyValue rdfs:subClassOf <Nfd1014361caf43e281b55bea9e37d926>
# <N6487c56edd7d432abc18437eb13f33d6> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ObjectNode
# 	Remove uml:ObjectNode rdfs:subClassOf <ub10bL541C9>
# 	http://bioprotocols.org/uml#ObjectNode rdfs:subClassOf <N6487c56edd7d432abc18437eb13f33d6>
# <N982602b1c42743e5bc5f10e9b9c94588> a owl:Restriction ;
# 	owl:onProperty uml:integerValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralInteger
# 	Remove uml:LiteralInteger rdfs:subClassOf <ub10bL112C9>
# 	http://bioprotocols.org/uml#LiteralInteger rdfs:subClassOf <N982602b1c42743e5bc5f10e9b9c94588>
# <Nb96ead27c54643eaa9ac3248495146c9> a owl:Restriction ;
# 	owl:onProperty uml:stringValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralString
# 	Remove uml:LiteralString rdfs:subClassOf <ub10bL99C5>
# 	http://bioprotocols.org/uml#LiteralString rdfs:subClassOf <Nb96ead27c54643eaa9ac3248495146c9>
# <Nf4cc85b991364bbbac7bf811bc3097ea> a owl:Restriction ;
# 	owl:onProperty uml:maxDurationValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <N3a02e56d1fa44b7e91e093ac69e83687> a owl:Restriction ;
# 	owl:onProperty uml:maxDurationValue ;
# 	owl:minCardinality <1>.
# <N65e534b52f6d4f388ca8a8f66e18ae55> a owl:Restriction ;
# 	owl:onProperty uml:maxDurationValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationInterval
# 	Remove uml:DurationInterval rdfs:subClassOf <ub10bL298C5>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <Nf4cc85b991364bbbac7bf811bc3097ea>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <N3a02e56d1fa44b7e91e093ac69e83687>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <N65e534b52f6d4f388ca8a8f66e18ae55>
# <Nf5c821910dd4476b87374b16378c3c19> a owl:Restriction ;
# 	owl:onProperty uml:integerValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralInteger
# 	Remove uml:LiteralInteger rdfs:subClassOf <ub10bL113C9>
# 	http://bioprotocols.org/uml#LiteralInteger rdfs:subClassOf <Nf5c821910dd4476b87374b16378c3c19>
# <N0ee9ffc5361f4ac6afdbfd38d86a3521> a owl:Restriction ;
# 	owl:onProperty uml:output ;
# 	owl:allValuesFrom uml:OutputPin.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Action
# 	Remove uml:Action rdfs:subClassOf <ub10bL570C5>
# 	http://bioprotocols.org/uml#Action rdfs:subClassOf <N0ee9ffc5361f4ac6afdbfd38d86a3521>
# <N11d26d27ebd242119a9f9ff23cb8d443> a owl:Restriction ;
# 	owl:onProperty uml:identifiedValue ;
# 	owl:allValuesFrom sbol:Identified.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralIdentified
# 	Remove uml:LiteralIdentified rdfs:subClassOf <ub10bL150C9>
# 	http://bioprotocols.org/uml#LiteralIdentified rdfs:subClassOf <N11d26d27ebd242119a9f9ff23cb8d443>
# <N01db2bbae2594297abfa919f0705da7a> a owl:Restriction ;
# 	owl:onProperty uml:decisionInput ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub10bL518C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <N01db2bbae2594297abfa919f0705da7a>
# <N305b808ccec846f1a6997acd03a23dcb> a owl:Restriction ;
# 	owl:onProperty uml:maxTimeValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# <N618e9db42cb2437183e15133cb4c3c0e> a owl:Restriction ;
# 	owl:onProperty uml:maxTimeValue ;
# 	owl:maxCardinality <1>.
# <N6d6637b59f8e4a16893fd36b4a955117> a owl:Restriction ;
# 	owl:onProperty uml:maxTimeValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeInterval
# 	Remove uml:TimeInterval rdfs:subClassOf <ub10bL276C5>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N305b808ccec846f1a6997acd03a23dcb>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N618e9db42cb2437183e15133cb4c3c0e>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N6d6637b59f8e4a16893fd36b4a955117>
# <Nd65191495c6445c0b4747ff338f1f456> a owl:Restriction ;
# 	owl:onProperty uml:behavior ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#CallBehaviorAction
# 	Remove uml:CallBehaviorAction rdfs:subClassOf <ub10bL607C9>
# 	http://bioprotocols.org/uml#CallBehaviorAction rdfs:subClassOf <Nd65191495c6445c0b4747ff338f1f456>
# <N41f426c3d2da48729d0c31313c27271f> a owl:Restriction ;
# 	owl:onProperty uml:edge ;
# 	owl:allValuesFrom uml:ActivityEdge.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Activity
# 	Remove uml:Activity rdfs:subClassOf <ub10bL460C5>
# 	http://bioprotocols.org/uml#Activity rdfs:subClassOf <N41f426c3d2da48729d0c31313c27271f>
# <Neba99496aac54842aac8793f999f5a06> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL627C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Neba99496aac54842aac8793f999f5a06>
# <Nf671a58356da4789bf801b93928f8a74> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <0>.
# <Nd715d13f798146899f22de4181a183df> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <2>.
# <N915d0c8388e3496296430e0f55dd5571> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationConstraint
# 	Remove uml:DurationConstraint rdfs:subClassOf <ub10bL351C5>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Nf671a58356da4789bf801b93928f8a74>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Nd715d13f798146899f22de4181a183df>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <N915d0c8388e3496296430e0f55dd5571>
# <N883d20f1b28a4763809dbf40d13c51e0> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL624C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N883d20f1b28a4763809dbf40d13c51e0>
# <Nd01573b3af3344f1b2a9e28f409aef73> a owl:Restriction ;
# 	owl:onProperty uml:timeObservationValue ;
# 	owl:maxCardinality <1>.
# <N71b3f757fb144277a34c825be782dec3> a owl:Restriction ;
# 	owl:onProperty uml:timeObservationValue ;
# 	owl:allValuesFrom sbol:Identified.
# <Na1decac29850475794e7f10f70a9f7b5> a owl:Restriction ;
# 	owl:onProperty uml:timeObservationValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeObservation
# 	Remove uml:TimeObservation rdfs:subClassOf <ub10bL234C5>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Nd01573b3af3344f1b2a9e28f409aef73>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N71b3f757fb144277a34c825be782dec3>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Na1decac29850475794e7f10f70a9f7b5>
# <Ncbac69c20c734cda9068b84482e0a644> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL625C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Ncbac69c20c734cda9068b84482e0a644>
# <Nfd7e997f7a544407ac5c302457dc2b29> a owl:Restriction ;
# 	owl:onProperty uml:value ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValuePin
# 	Remove uml:ValuePin rdfs:subClassOf <ub10bL640C5>
# 	http://bioprotocols.org/uml#ValuePin rdfs:subClassOf <Nfd7e997f7a544407ac5c302457dc2b29>
# <N474e4146c2754879a8764d0dc574f2a9> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL377C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N474e4146c2754879a8764d0dc574f2a9>
# <Nfe7a5bb1bb964658af6f20ba203f5adc> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValueSpecification
# 	Remove uml:ValueSpecification rdfs:subClassOf <ub10bL83C20>
# 	http://bioprotocols.org/uml#ValueSpecification rdfs:subClassOf <Nfe7a5bb1bb964658af6f20ba203f5adc>
# <Nd77d9b919015499089d17d4fda6fc32a> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL383C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Nd77d9b919015499089d17d4fda6fc32a>
# <N91f611b19a924125a41c7623e46c67aa> a owl:Restriction ;
# 	owl:onProperty uml:defaultValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL370C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N91f611b19a924125a41c7623e46c67aa>
# <N598d3ef0c86244f8bf60f6951767904e> a owl:Restriction ;
# 	owl:onProperty uml:precondition ;
# 	owl:allValuesFrom uml:Constraint.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Behavior
# 	Remove uml:Behavior rdfs:subClassOf <ub10bL405C5>
# 	http://bioprotocols.org/uml#Behavior rdfs:subClassOf <N598d3ef0c86244f8bf60f6951767904e>
# <N70c2ccb284704a6d8d8bb14f3ed3ba3e> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL622C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N70c2ccb284704a6d8d8bb14f3ed3ba3e>
# <N9d74d172bee54313b16042ec0e1c7752> a owl:Restriction ;
# 	owl:onProperty uml:integerValue ;
# 	owl:allValuesFrom xsd:integer.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralInteger
# 	Remove uml:LiteralInteger rdfs:subClassOf <ub10bL111C9>
# 	http://bioprotocols.org/uml#LiteralInteger rdfs:subClassOf <N9d74d172bee54313b16042ec0e1c7752>
# <N1a85b1a1ede74faa888d81d999b79b39> a owl:Restriction ;
# 	owl:onProperty uml:target ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub10bL665C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <N1a85b1a1ede74faa888d81d999b79b39>
# <N5e54a0969d3b45c385f0245610cb33b4> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValueSpecification
# 	Remove uml:ValueSpecification rdfs:subClassOf <ub10bL84C20>
# 	http://bioprotocols.org/uml#ValueSpecification rdfs:subClassOf <N5e54a0969d3b45c385f0245610cb33b4>
# <Nfff329e2264a4e1e8a212f792932c781> a owl:Restriction ;
# 	owl:onProperty uml:stringValue ;
# 	owl:allValuesFrom xsd:string.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralString
# 	Remove uml:LiteralString rdfs:subClassOf <ub10bL98C5>
# 	http://bioprotocols.org/uml#LiteralString rdfs:subClassOf <Nfff329e2264a4e1e8a212f792932c781>
# <N246673811c3b4d0fbc482d2d200f9bef> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL373C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N246673811c3b4d0fbc482d2d200f9bef>
# <Nff2b0c5f61eb421b9c3098c7b52f2e2d> a owl:Restriction ;
# 	owl:onProperty uml:durationObservationValue ;
# 	owl:allValuesFrom sbol:Identified.
# <Nf7067a46d81342d6b9c97c1c0d61c86d> a owl:Restriction ;
# 	owl:onProperty uml:durationObservationValue ;
# 	owl:minCardinality <1>.
# <Ne494a76807824f1f806c2abfff9a4e92> a owl:Restriction ;
# 	owl:onProperty uml:durationObservationValue ;
# 	owl:maxCardinality <2>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationObservation
# 	Remove uml:DurationObservation rdfs:subClassOf <ub10bL243C5>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <Nff2b0c5f61eb421b9c3098c7b52f2e2d>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <Nf7067a46d81342d6b9c97c1c0d61c86d>
# 	http://bioprotocols.org/uml#DurationObservation rdfs:subClassOf <Ne494a76807824f1f806c2abfff9a4e92>
# <Nebaec782127140e2b796ddc27dc37513> a owl:Restriction ;
# 	owl:onProperty uml:decisionInputFlow ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DecisionNode
# 	Remove uml:DecisionNode rdfs:subClassOf <ub10bL520C5>
# 	http://bioprotocols.org/uml#DecisionNode rdfs:subClassOf <Nebaec782127140e2b796ddc27dc37513>
# <N5c7a7294ee4f47968e2164fa602df4dc> a owl:Restriction ;
# 	owl:onProperty uml:identifiedValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralIdentified
# 	Remove uml:LiteralIdentified rdfs:subClassOf <ub10bL152C9>
# 	http://bioprotocols.org/uml#LiteralIdentified rdfs:subClassOf <N5c7a7294ee4f47968e2164fa602df4dc>
# <N4d42490d14a349c6a814dcdb7db097a6> a owl:Restriction ;
# 	owl:onProperty uml:parameter ;
# 	owl:allValuesFrom uml:Parameter.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityParameterNode
# 	Remove uml:ActivityParameterNode rdfs:subClassOf <ub10bL548C9>
# 	http://bioprotocols.org/uml#ActivityParameterNode rdfs:subClassOf <N4d42490d14a349c6a814dcdb7db097a6>
# <Ne8433b821ff140c9a8afed719003398b> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <1>.
# <N1928accdacb24b0c8536bb5feb6ba993> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# <N93b66c95bc6e4d5dbd15460309103394> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <0>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeConstraint
# 	Remove uml:TimeConstraint rdfs:subClassOf <ub10bL336C5>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <Ne8433b821ff140c9a8afed719003398b>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N1928accdacb24b0c8536bb5feb6ba993>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N93b66c95bc6e4d5dbd15460309103394>
# <N0eebd8ea526e444891ded95759a6ede6> a owl:Restriction ;
# 	owl:onProperty uml:observationValue ;
# 	owl:allValuesFrom uml:Observation.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeExpression
# 	Remove uml:TimeExpression rdfs:subClassOf <ub10bL200C5>
# 	http://bioprotocols.org/uml#TimeExpression rdfs:subClassOf <N0eebd8ea526e444891ded95759a6ede6>
# <N302253d266cf401e8208e29ea4f0f1a1> a owl:Restriction ;
# 	owl:onProperty uml:booleanValue ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralBoolean
# 	Remove uml:LiteralBoolean rdfs:subClassOf <ub10bL124C9>
# 	http://bioprotocols.org/uml#LiteralBoolean rdfs:subClassOf <N302253d266cf401e8208e29ea4f0f1a1>
# <Nf09009e58c1a4745a20eae163b8708d8> a owl:Restriction ;
# 	owl:onProperty uml:durationSpecification ;
# 	owl:maxCardinality <1>.
# <N63d7a1149cc74f1fb3bbd3fa6ae87065> a owl:Restriction ;
# 	owl:onProperty uml:durationSpecification ;
# 	owl:minCardinality <1>.
# <N3f2aeeac35654406b8b15faa4e697c05> a owl:Restriction ;
# 	owl:onProperty uml:durationSpecification ;
# 	owl:onClass uml:DurationInterval.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationConstraint
# 	Remove uml:DurationConstraint rdfs:subClassOf <ub10bL349C5>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <Nf09009e58c1a4745a20eae163b8708d8>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <N63d7a1149cc74f1fb3bbd3fa6ae87065>
# 	http://bioprotocols.org/uml#DurationConstraint rdfs:subClassOf <N3f2aeeac35654406b8b15faa4e697c05>
# <N3cd306c62b3d4c48b3f3457306474779> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL384C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N3cd306c62b3d4c48b3f3457306474779>
# <N808b3bbcd00b49a0a8bd9cab6f17f5e7> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL381C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N808b3bbcd00b49a0a8bd9cab6f17f5e7>
# <Ne91eab08da1a4ba2b419d38d2eaa5772> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:minCardinality <1>.
# <Ne65c224ce79c4aeea66fc743ad38a21a> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# <N1827f47458da4f4db535e629b69d34a2> a owl:Restriction ;
# 	owl:onProperty uml:firstEventValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeObservation
# 	Remove uml:TimeObservation rdfs:subClassOf <ub10bL232C5>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Ne91eab08da1a4ba2b419d38d2eaa5772>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <Ne65c224ce79c4aeea66fc743ad38a21a>
# 	http://bioprotocols.org/uml#TimeObservation rdfs:subClassOf <N1827f47458da4f4db535e629b69d34a2>
# <N08398f482cf941ec993d6a8aaaea8b24> a owl:Restriction ;
# 	owl:onProperty uml:value ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ValuePin
# 	Remove uml:ValuePin rdfs:subClassOf <ub10bL641C5>
# 	http://bioprotocols.org/uml#ValuePin rdfs:subClassOf <N08398f482cf941ec993d6a8aaaea8b24>
# <N283e04751adc42629915d7b1f078b21a> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL626C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N283e04751adc42629915d7b1f078b21a>
# <N05f7f265635e444b9cfcce3cd0955442> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL628C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N05f7f265635e444b9cfcce3cd0955442>
# <N58fdb9c82c9845f892ac1bb4d4b43142> a owl:Restriction ;
# 	owl:onProperty uml:minTimeValue ;
# 	owl:maxCardinality <1>.
# <Nc86cae4dab91470ea2f90bffb431209a> a owl:Restriction ;
# 	owl:onProperty uml:minTimeValue ;
# 	owl:minCardinality <1>.
# <N5b0993bcec19474fa7759dd6ee10da12> a owl:Restriction ;
# 	owl:onProperty uml:minTimeValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeInterval
# 	Remove uml:TimeInterval rdfs:subClassOf <ub10bL274C5>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N58fdb9c82c9845f892ac1bb4d4b43142>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <Nc86cae4dab91470ea2f90bffb431209a>
# 	http://bioprotocols.org/uml#TimeInterval rdfs:subClassOf <N5b0993bcec19474fa7759dd6ee10da12>
# <N17d9538866714313beeb12f975089668> a owl:Restriction ;
# 	owl:onProperty uml:realValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReal
# 	Remove uml:LiteralReal rdfs:subClassOf <ub10bL138C9>
# 	http://bioprotocols.org/uml#LiteralReal rdfs:subClassOf <N17d9538866714313beeb12f975089668>
# <N9695efd496a44352878c0bc4e0e9fb19> a owl:Restriction ;
# 	owl:onProperty uml:timeSpecification ;
# 	owl:onClass uml:TimeInterval.
# <Nd16a546cf10749b99344071659b316c4> a owl:Restriction ;
# 	owl:onProperty uml:timeSpecification ;
# 	owl:minCardinality <1>.
# <N566cefbac7004aba82c52ef9c70a84ce> a owl:Restriction ;
# 	owl:onProperty uml:timeSpecification ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#TimeConstraint
# 	Remove uml:TimeConstraint rdfs:subClassOf <ub10bL334C5>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N9695efd496a44352878c0bc4e0e9fb19>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <Nd16a546cf10749b99344071659b316c4>
# 	http://bioprotocols.org/uml#TimeConstraint rdfs:subClassOf <N566cefbac7004aba82c52ef9c70a84ce>
# <N764b8dda9e914661b60b38df17b26f01> a owl:Restriction ;
# 	owl:onProperty uml:ownedParameter ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Behavior
# 	Remove uml:Behavior rdfs:subClassOf <ub10bL407C5>
# 	http://bioprotocols.org/uml#Behavior rdfs:subClassOf <N764b8dda9e914661b60b38df17b26f01>
# <Neffed150f26f40d78ba5a0a3622bdc41> a owl:Restriction ;
# 	owl:onProperty uml:direction ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL367C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Neffed150f26f40d78ba5a0a3622bdc41>
# <N6af1a5e874c24aaca432c777d132a187> a owl:Restriction ;
# 	owl:onProperty uml:constrainedElement ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Constraint
# 	Remove uml:Constraint rdfs:subClassOf <ub10bL319C9>
# 	http://bioprotocols.org/uml#Constraint rdfs:subClassOf <N6af1a5e874c24aaca432c777d132a187>
# <Na85c0c8259944155b4bfa89c10f8b69e> a owl:Restriction ;
# 	owl:onProperty uml:upperValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL629C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Na85c0c8259944155b4bfa89c10f8b69e>
# <N75b661d359b54835b0c34ad8baa16bce> a owl:Restriction ;
# 	owl:onProperty uml:behavior ;
# 	owl:allValuesFrom uml:Behavior.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#CallBehaviorAction
# 	Remove uml:CallBehaviorAction rdfs:subClassOf <ub10bL606C9>
# 	http://bioprotocols.org/uml#CallBehaviorAction rdfs:subClassOf <N75b661d359b54835b0c34ad8baa16bce>
# <Nd6ab1a9b1540441dac43af0236a554ae> a owl:Restriction ;
# 	owl:onProperty uml:parameter ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityParameterNode
# 	Remove uml:ActivityParameterNode rdfs:subClassOf <ub10bL549C9>
# 	http://bioprotocols.org/uml#ActivityParameterNode rdfs:subClassOf <Nd6ab1a9b1540441dac43af0236a554ae>
# <N58330f9d86084e85862b18f17bfcc9f0> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL380C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N58330f9d86084e85862b18f17bfcc9f0>
# <N67bb47af9bf444eda136095b20427fa9> a owl:Restriction ;
# 	owl:onProperty uml:type ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ObjectNode
# 	Remove uml:ObjectNode rdfs:subClassOf <ub10bL542C9>
# 	http://bioprotocols.org/uml#ObjectNode rdfs:subClassOf <N67bb47af9bf444eda136095b20427fa9>
# <N66bdcc7ae3554203bbe93c13d727132b> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL379C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N66bdcc7ae3554203bbe93c13d727132b>
# <Ncf96b68491e6469190dcfbfd196a5b1f> a owl:Restriction ;
# 	owl:onProperty uml:isUnique ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL623C9>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <Ncf96b68491e6469190dcfbfd196a5b1f>
# <N7f518b2d635549509c9ff7a8cb0ca84b> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL376C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N7f518b2d635549509c9ff7a8cb0ca84b>
# <N608046c863f64b4f9c99c17f63bb406a> a owl:Restriction ;
# 	owl:onProperty uml:input ;
# 	owl:allValuesFrom uml:InputPin.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Action
# 	Remove uml:Action rdfs:subClassOf <ub10bL569C5>
# 	http://bioprotocols.org/uml#Action rdfs:subClassOf <N608046c863f64b4f9c99c17f63bb406a>
# <N0d7f5d5637404136bcacc5d307d35ad4> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL375C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N0d7f5d5637404136bcacc5d307d35ad4>
# <N3ea1d9c5e2464e2eb4810a04da6bf908> a owl:Restriction ;
# 	owl:onProperty uml:direction ;
# 	owl:allValuesFrom xsd:anyURI.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL366C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N3ea1d9c5e2464e2eb4810a04da6bf908>
# <N23a21409ed734658bfaf880386abbf84> a owl:Restriction ;
# 	owl:onProperty uml:lowerValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL382C5>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N23a21409ed734658bfaf880386abbf84>
# <N70c4b598653e4b48aa4bc9d93e049392> a owl:Restriction ;
# 	owl:onProperty uml:minDurationValue ;
# 	owl:minCardinality <1>.
# <Nf7ba27a4d0064379b687cc767283bb42> a owl:Restriction ;
# 	owl:onProperty uml:minDurationValue ;
# 	owl:maxCardinality <1>.
# <Ndd922187724745bc999d070678799db3> a owl:Restriction ;
# 	owl:onProperty uml:minDurationValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#DurationInterval
# 	Remove uml:DurationInterval rdfs:subClassOf <ub10bL296C5>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <N70c4b598653e4b48aa4bc9d93e049392>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <Nf7ba27a4d0064379b687cc767283bb42>
# 	http://bioprotocols.org/uml#DurationInterval rdfs:subClassOf <Ndd922187724745bc999d070678799db3>
# <Nc01b119e072644f78fa6796b2e3da5f3> a owl:Restriction ;
# 	owl:onProperty uml:source ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub10bL662C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <Nc01b119e072644f78fa6796b2e3da5f3>
# <N9b68a10fb59343159d2421b6625d21e4> a owl:Restriction ;
# 	owl:onProperty uml:identifiedValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralIdentified
# 	Remove uml:LiteralIdentified rdfs:subClassOf <ub10bL151C9>
# 	http://bioprotocols.org/uml#LiteralIdentified rdfs:subClassOf <N9b68a10fb59343159d2421b6625d21e4>
# <Nf63b3d1a80c64f9fae3b43122394b040> a owl:Restriction ;
# 	owl:onProperty uml:direction ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL368C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <Nf63b3d1a80c64f9fae3b43122394b040>
# <N5c3c5453636740789aac440d9491b58b> a owl:Restriction ;
# 	owl:onProperty uml:target ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub10bL664C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <N5c3c5453636740789aac440d9491b58b>
# <N8f58a92195ee44a299b7876003c7c32a> a owl:Restriction ;
# 	owl:onProperty uml:realValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReal
# 	Remove uml:LiteralReal rdfs:subClassOf <ub10bL139C9>
# 	http://bioprotocols.org/uml#LiteralReal rdfs:subClassOf <N8f58a92195ee44a299b7876003c7c32a>
# <Nd88a07ee3d2248c0b65cb582e90c8858> a owl:Restriction ;
# 	owl:onProperty uml:booleanValue ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralBoolean
# 	Remove uml:LiteralBoolean rdfs:subClassOf <ub10bL125C9>
# 	http://bioprotocols.org/uml#LiteralBoolean rdfs:subClassOf <Nd88a07ee3d2248c0b65cb582e90c8858>
# <N200bdae761fd48e3b839869bd3e86811> a owl:Restriction ;
# 	owl:onProperty uml:observationValue ;
# 	owl:allValuesFrom uml:Observation.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Duration
# 	Remove uml:Duration rdfs:subClassOf <ub10bL207C5>
# 	http://bioprotocols.org/uml#Duration rdfs:subClassOf <N200bdae761fd48e3b839869bd3e86811>
# <Nac64301c5e5347e6ba11aa63eeafb3b9> a owl:Restriction ;
# 	owl:onProperty uml:target ;
# 	owl:allValuesFrom uml:ActivityNode.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub10bL663C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <Nac64301c5e5347e6ba11aa63eeafb3b9>
# <N3e01947985fd44f799082f5e11791f2a> a owl:Restriction ;
# 	owl:onProperty uml:operandValue ;
# 	owl:allValuesFrom uml:OrderedPropertyValue.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Expression
# 	Remove uml:Expression rdfs:subClassOf <ub10bL180C5>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N3e01947985fd44f799082f5e11791f2a>
# <N1e09518570284b39842a1cc3ec542590> a owl:Restriction ;
# 	owl:onProperty uml:defaultValue ;
# 	owl:allValuesFrom uml:ValueSpecification.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Parameter
# 	Remove uml:Parameter rdfs:subClassOf <ub10bL369C9>
# 	http://bioprotocols.org/uml#Parameter rdfs:subClassOf <N1e09518570284b39842a1cc3ec542590>
# <N34f2653756d640dea1874058b3b8a9b5> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:allValuesFrom xsd:boolean.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Pin
# 	Remove uml:Pin rdfs:subClassOf <ub10bL620C14>
# 	http://bioprotocols.org/uml#Pin rdfs:subClassOf <N34f2653756d640dea1874058b3b8a9b5>
# <Nc0763ecf3fe4432f94669dd4bad7ce62> a owl:Restriction ;
# 	owl:onProperty uml:realValue ;
# 	owl:allValuesFrom xsd:float.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralReal
# 	Remove uml:LiteralReal rdfs:subClassOf <ub10bL137C9>
# 	http://bioprotocols.org/uml#LiteralReal rdfs:subClassOf <Nc0763ecf3fe4432f94669dd4bad7ce62>
# <Nb927a21872594b8b901cf6499c73dbe7> a owl:Restriction ;
# 	owl:onProperty uml:source ;
# 	owl:allValuesFrom uml:ActivityNode.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#ActivityEdge
# 	Remove uml:ActivityEdge rdfs:subClassOf <ub10bL660C5>
# 	http://bioprotocols.org/uml#ActivityEdge rdfs:subClassOf <Nb927a21872594b8b901cf6499c73dbe7>
# <N1e6d3b3b9ea840e19e72519c100559d1> a owl:Restriction ;
# 	owl:onProperty uml:stringValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#LiteralString
# 	Remove uml:LiteralString rdfs:subClassOf <ub10bL100C5>
# 	http://bioprotocols.org/uml#LiteralString rdfs:subClassOf <N1e6d3b3b9ea840e19e72519c100559d1>
# <N7115147dd10242c199791e5bb172e6cb> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:allValuesFrom xsd:boolean.
# <N18d958a397954d328e7a5f8d37966db6> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:maxCardinality <1>.
# <N522e903ac7ad417499002d83790f7819> a owl:Restriction ;
# 	owl:onProperty uml:isOrdered ;
# 	owl:minCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Expression
# 	Remove uml:Expression rdfs:subClassOf <ub10bL178C5>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N7115147dd10242c199791e5bb172e6cb>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N18d958a397954d328e7a5f8d37966db6>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N522e903ac7ad417499002d83790f7819>
# <N40646d61b1ca4f3393c76d5f290c1637> a owl:Restriction ;
# 	owl:onProperty uml:symbolValue ;
# 	owl:minCardinality <0>.
# <N0deb527c8c2244bb943f96e2ccf7b144> a owl:Restriction ;
# 	owl:onProperty uml:symbolValue ;
# 	owl:allValuesFrom xsd:string.
# <Ne1ef63bec6e247f4ad2c0c2fb0831621> a owl:Restriction ;
# 	owl:onProperty uml:symbolValue ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#Expression
# 	Remove uml:Expression rdfs:subClassOf <ub10bL176C5>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N40646d61b1ca4f3393c76d5f290c1637>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <N0deb527c8c2244bb943f96e2ccf7b144>
# 	http://bioprotocols.org/uml#Expression rdfs:subClassOf <Ne1ef63bec6e247f4ad2c0c2fb0831621>
# <N786da27811ce46d39b7919fb8d59c4f8> a owl:Restriction ;
# 	owl:onProperty uml:behavior ;
# 	owl:maxCardinality <1>.
# Children of this restriction are:
# 	http://bioprotocols.org/uml#CallBehaviorAction
# 	Remove uml:CallBehaviorAction rdfs:subClassOf <ub10bL608C9>
# 	http://bioprotocols.org/uml#CallBehaviorAction rdfs:subClassOf <N786da27811ce46d39b7919fb8d59c4f8>
# <Graph identifier=N4b054f7e0a6f437cb224cde002193bbe (<class 'rdflib.graph.Graph'>)>

# %%
g.serialize(destination='uml-original.nt')

# %%
new_g.serialize(destination='uml-revised.nt')

# %%
new_g.serialize(destination='uml-revised.ttl', format='turtle')
